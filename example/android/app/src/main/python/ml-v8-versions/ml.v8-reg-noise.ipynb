# %%
from datetime import datetime
import numpy as np
import xgboost as xgb

# %load_ext memory_profiler

# %%
import matplotlib.pyplot as plt

# %matplotlib inline
plt.rcParams['figure.figsize'] = [18, 6]

# %%
from pipeline_v1.mb import MoodBoost
from pipeline_v1.optimizing import SubjectwiseCrossVal, MoodBoostOptimizer
from pipeline_v1.signal_pross import get_hr, min_max_scale
from pipeline_v1.truth import IeeeGroundTruth

# %% [markdown]
# ## 1. Process and align RGB data from video with ground truth BVP data

# %%
truths = []
noisy_truths = []
dim_truths = []
bright_truths = []

for subject in range(1, 8):

    truth = IeeeGroundTruth(subject, 1, directory = 'pipeline_v1/channel_data3')  # we only use the first trial for each subject
    truth_noisy = IeeeGroundTruth(subject, 1, directory = 'pipeline_v1/channel_data3_noise', noisy = True)
    truth_dim = IeeeGroundTruth(subject, 1, directory = 'pipeline_v1/channel_data3_dim', dim = True)
    truth_bright = IeeeGroundTruth(subject, 1, directory = 'pipeline_v1/channel_data3_bright', bright = True)
    
    truth.align_rgb_bvp()
    truth_noisy.align_rgb_bvp()
    truth_dim.align_rgb_bvp()
    truth_bright.align_rgb_bvp()

    truth.fill_nans()
    truth_noisy.fill_nans()
    truth_dim.fill_nans()
    truth_bright.fill_nans()

    truth.process_rgb(
        minmax = False,
        use_wavelet = True,
        use_bandpass = False
    )
    truth_noisy.process_rgb(
        minmax = False,
        use_wavelet = True,
        use_bandpass = False
    )
    truth_dim.process_rgb(
        minmax = False,
        use_wavelet = True,
        use_bandpass = False
    )
    truth_bright.process_rgb(
        minmax = False,
        use_wavelet = True,
        use_bandpass = False
    )

    truth.process_bvp()
    truth_noisy.process_bvp()
    truth_dim.process_bvp()
    truth_bright.process_bvp()

    truths.append(truth)
    noisy_truths.append(truth_noisy)
    dim_truths.append(truth_dim)
    bright_truths.append(truth_bright)

testing_truths = noisy_truths + dim_truths + bright_truths

# %% [markdown]
# ## 2. Train the model and validate using subject 7

# %%
test_subject = 7
test_subject_truth = truths[test_subject - 1]

mod = MoodBoost(
    truths, random_state = None, loss_type = 'combined',
    n_estimators = 188, split_size = 960, learning_rate = 0.001,
    early_stopping_rounds = 16, mse_weight = 0.2, dtw_weight = 0.8, data_beg = 8000, data_end = 10180,
    batches = 5, min_bandpass_freq = 0.7, max_bandpass_freq = 4.0, bandpass_order = 4,
    predicted_peaks_prominence = 0.28,
    true_peaks_prominence = 0.322741927274642, 
    max_depth = 6, max_bin = 235, num_feats_per_channel = 8, skip_amount = 12, finetune = True
)
mod.fit()
# Out:
# Number of samples in dataset: 13080
#
#
# On batch 1 of 5:
# [0]	train-rmse:0.95788	train-hr_err:0.90644	test-rmse:0.81575	test-hr_err:19.93113
# [5]	train-rmse:0.96224	train-hr_err:0.90644	test-rmse:0.81756	test-hr_err:17.95458
# [10]	train-rmse:0.96659	train-hr_err:0.78938	test-rmse:0.81938	test-hr_err:17.95458
# [15]	train-rmse:0.97094	train-hr_err:0.78938	test-rmse:0.82124	test-hr_err:16.83178
# [20]	train-rmse:0.97525	train-hr_err:0.78938	test-rmse:0.82385	test-hr_err:16.79716
# [25]	train-rmse:0.97955	train-hr_err:0.78938	test-rmse:0.82665	test-hr_err:16.90484
# [30]	train-rmse:0.98384	train-hr_err:0.78938	test-rmse:0.82947	test-hr_err:12.43639
# [35]	train-rmse:0.98811	train-hr_err:0.78938	test-rmse:0.83233	test-hr_err:15.74810
# [40]	train-rmse:0.99237	train-hr_err:0.78938	test-rmse:0.83478	test-hr_err:15.79257
# [43]	train-rmse:0.99491	train-hr_err:0.78938	test-rmse:0.83583	test-hr_err:18.13403
# Fintuning...
# [0]	train-rmse:1.37076	train-hr_err:0.90909	test-rmse:0.83527	test-hr_err:18.13403
# [5]	train-rmse:1.36472	train-hr_err:0.90909	test-rmse:0.83108	test-hr_err:16.94329
# [10]	train-rmse:1.35871	train-hr_err:1.33172	test-rmse:0.82696	test-hr_err:18.47907
# [15]	train-rmse:1.35273	train-hr_err:1.33172	test-rmse:0.82292	test-hr_err:11.96246
# [20]	train-rmse:1.34678	train-hr_err:3.00726	test-rmse:0.81895	test-hr_err:14.18201
# [22]	train-rmse:1.34441	train-hr_err:3.00726	test-rmse:0.81739	test-hr_err:14.34657
#
#
# On batch 2 of 5:
# [0]	train-rmse:0.83547	train-hr_err:2.41591	test-rmse:0.81674	test-hr_err:12.16110
# [5]	train-rmse:0.83983	train-hr_err:2.12718	test-rmse:0.81752	test-hr_err:13.23200
# [10]	train-rmse:0.84420	train-hr_err:2.41591	test-rmse:0.81837	test-hr_err:9.31698
# [15]	train-rmse:0.84856	train-hr_err:1.06944	test-rmse:0.81926	test-hr_err:8.52679
# [20]	train-rmse:0.85292	train-hr_err:1.06944	test-rmse:0.82020	test-hr_err:7.01041
# [25]	train-rmse:0.85726	train-hr_err:3.18776	test-rmse:0.82130	test-hr_err:6.84834
# [30]	train-rmse:0.86160	train-hr_err:3.18776	test-rmse:0.82250	test-hr_err:8.07509
# [33]	train-rmse:0.86420	train-hr_err:3.18776	test-rmse:0.82321	test-hr_err:8.71774
# Fintuning...
# [0]	train-rmse:1.25558	train-hr_err:3.18776	test-rmse:0.82273	test-hr_err:7.62930
# [5]	train-rmse:1.24978	train-hr_err:3.11233	test-rmse:0.82035	test-hr_err:7.86179
# [10]	train-rmse:1.24401	train-hr_err:3.11233	test-rmse:0.81800	test-hr_err:6.89692
#
#
# On batch 3 of 5:
# [0]	train-rmse:0.95382	train-hr_err:8.41437	test-rmse:0.81842	test-hr_err:6.89692
# [5]	train-rmse:0.95737	train-hr_err:12.90904	test-rmse:0.82053	test-hr_err:5.91780
# [10]	train-rmse:0.96093	train-hr_err:13.92527	test-rmse:0.82264	test-hr_err:6.26995
# [15]	train-rmse:0.96449	train-hr_err:14.01393	test-rmse:0.82479	test-hr_err:9.96990
# [18]	train-rmse:0.96663	train-hr_err:18.70668	test-rmse:0.82610	test-hr_err:11.32920
# Fintuning...
# [0]	train-rmse:1.31632	train-hr_err:18.80710	test-rmse:0.82569	test-hr_err:10.81239
# [5]	train-rmse:1.31112	train-hr_err:14.11435	test-rmse:0.82189	test-hr_err:9.51348
# [10]	train-rmse:1.30593	train-hr_err:17.49385	test-rmse:0.81805	test-hr_err:9.39447
# [15]	train-rmse:1.30077	train-hr_err:8.78718	test-rmse:0.81423	test-hr_err:8.31239
# [20]	train-rmse:1.29564	train-hr_err:8.69660	test-rmse:0.81044	test-hr_err:9.43428
# [21]	train-rmse:1.29462	train-hr_err:8.69660	test-rmse:0.80968	test-hr_err:9.43428
#
#
# On batch 4 of 5:
# [0]	train-rmse:0.85652	train-hr_err:5.96381	test-rmse:0.80990	test-hr_err:9.43428
# [5]	train-rmse:0.85983	train-hr_err:10.51748	test-rmse:0.81098	test-hr_err:9.88599
# [10]	train-rmse:0.86316	train-hr_err:11.52311	test-rmse:0.81210	test-hr_err:9.85188
# [15]	train-rmse:0.86652	train-hr_err:10.51748	test-rmse:0.81330	test-hr_err:9.03343
# [19]	train-rmse:0.86921	train-hr_err:10.51748	test-rmse:0.81426	test-hr_err:9.03343
# Fintuning...
# [0]	train-rmse:1.25283	train-hr_err:10.51748	test-rmse:0.81366	test-hr_err:9.03343
# [5]	train-rmse:1.24756	train-hr_err:11.44242	test-rmse:0.81070	test-hr_err:9.05175
# [10]	train-rmse:1.24231	train-hr_err:11.52311	test-rmse:0.80779	test-hr_err:9.85188
# [12]	train-rmse:1.24023	train-hr_err:11.52311	test-rmse:0.80664	test-hr_err:9.28798
#
#
# On batch 5 of 5:
# [0]	train-rmse:0.95486	train-hr_err:29.04956	test-rmse:0.80684	test-hr_err:8.18958
# [5]	train-rmse:0.95898	train-hr_err:24.62263	test-rmse:0.80788	test-hr_err:5.46004
# [10]	train-rmse:0.96311	train-hr_err:16.06196	test-rmse:0.80896	test-hr_err:6.41864
# [15]	train-rmse:0.96724	train-hr_err:16.06196	test-rmse:0.81009	test-hr_err:5.37318
# [20]	train-rmse:0.97137	train-hr_err:16.06196	test-rmse:0.81119	test-hr_err:6.40472
# [25]	train-rmse:0.97550	train-hr_err:15.95446	test-rmse:0.81240	test-hr_err:4.76555
# [30]	train-rmse:0.97969	train-hr_err:16.06196	test-rmse:0.81344	test-hr_err:4.76380
# [35]	train-rmse:0.98390	train-hr_err:11.73276	test-rmse:0.81449	test-hr_err:10.72182
# [36]	train-rmse:0.98474	train-hr_err:11.73276	test-rmse:0.81470	test-hr_err:10.72182
# Fintuning...
# [0]	train-rmse:1.35329	train-hr_err:11.73276	test-rmse:0.81430	test-hr_err:10.70081
# [5]	train-rmse:1.34740	train-hr_err:16.16921	test-rmse:0.81127	test-hr_err:7.38714
# [10]	train-rmse:1.34154	train-hr_err:16.16921	test-rmse:0.80829	test-hr_err:10.23602
# [15]	train-rmse:1.33572	train-hr_err:16.06196	test-rmse:0.80537	test-hr_err:11.16721
# Finished training in 0:01:33.069709

# %% [markdown]
# ## 2.5. Save the model

# %%
mod.save('moodboost.xgb')

# %% [markdown]
# ## Print the model stats

# %%
mse, hr_err, hrv_err = mod.eval()

print(f'\n\nMSE: {mse}')
print(f'HR error: {hr_err}')
print(f'HR error squared: {hrv_err}\n\n')

mod.get_model_stats()
mod.plot_hr_loss()
# Out:
# MSE: 0.12341568824107915
# HR error: 13.87490254473434
# HR error squared: 196.00083633403074
#
#
# Best test loss: 4.574466
#
#
# Feature importances:
#    feature  importance
# 0      f32   41.628784
# 1      f29   32.781120
# 2      f17   31.976179
# 3      f19   28.968117
# 4      f28   28.603857
# 5       f3   28.241325
# 6      f15   27.926579
# 7      f20   25.120909
# 8      f16   22.911545
# 9       f1   22.331276
# 10     f18   21.949257
# 11     f25   21.580633
# 12     f30   21.204454
# 13      f4   20.728760
# 14     f26   20.425369
# 15     f24   20.087629
# 16     f23   20.066708
# 17     f21   19.258240
# 18     f27   19.131075
# 19     f22   16.868622
# 20     f33   13.528689
# 21     f13   12.578734
# 22     f14   11.717709
# 23     f31   11.714657
# 24      f9   11.502473
# 25      f5    9.787425
# 26      f2    5.977160
# 27      f0    3.893966
# 28      f6    1.246608
# 29      f8    0.400880

# %% [markdown]
# ## Plot the predicted signal versus its ground truth

# %%
# beginning point from which to plot
beg = 3000
end = beg + 960  # we add 960 bc that's the period which HR error is calculated; it's also the amount of user video needed to calculate HR error (15s)

# prepare test subject data for ML, and give it the corresponding mem feats (8 mem feat, 12 skip amount)
data = test_subject_truth.prepare_data_for_ml(8, 12)

# get input data and target data
X = xgb.DMatrix(data.drop(columns = ['bvp']).to_numpy())
y = data['bvp'].to_numpy()

# get the model predictions in this method so that RAM usage is measured accurately
def measure_code_block():
    t = datetime.today()
    targ = y[beg: end]
    pred = mod.predict(X)
    pred = pred[beg: end]
    targ, pred = mod.process_signal(targ, pred, use_bandpass=True)
    elapsed_time = datetime.today() - t
    return targ, pred, elapsed_time

# measure the RAM usage of the model while also getting the predictions and processing both predictions and targets
# %memit targ, pred, elapsed_time = measure_code_block()
print('Time elapsed:', elapsed_time)

# get the predicted and true peaks for each signal
pred_peaks, _ = mod.get_predicted_peaks(pred)
true_peaks, _ = mod.get_true_peaks(targ)

# create the plot
plt.plot(targ, linestyle = '--', label = 'Ground Truth')
plt.plot(pred, label = 'Predictions')
plt.legend()
plt.title(f'Subject {test_subject} predicted signal vs. ground truth', fontsize = 20)

# modify plot appearance
plt.gca().spines['top'].set_color('none')
plt.gca().spines['right'].set_color('none')
plt.gca().xaxis.set_ticks_position('bottom')
plt.gca().yaxis.set_ticks_position('left')

# plot the peaks
plt.scatter(pred_peaks, pred[pred_peaks], c='r')
plt.scatter(true_peaks, targ[true_peaks], c='g')

# compute the predicted and true HR for this block
pred_ibis = np.diff(pred_peaks) / 64
true_ibis = np.diff(true_peaks) / 64
pred_hr = get_hr(pred_ibis)
true_hr = get_hr(true_ibis)
print(f'True HR: {true_hr}; Pred HR: {pred_hr}')
# Out:
# peak memory: 211.04 MiB, increment: 0.05 MiB
# Time elapsed: 0:00:00.073025
# True HR: 49.10485933503836; Pred HR: 80.84210526315789

# %% [markdown]
# ## 4. Apply cross-validation to validate performance

# %%
special_truths = {}
for i in range(1, 8):
    special_truths[i] = {
        'training': [truths[i - 1], noisy_truths[i - 1]],
        'testing': [dim_truths[i - 1], bright_truths[i - 1]]
    }

rpm = 5
res = SubjectwiseCrossVal(
    special_truths, random_state = None, loss_type = 'combined', rounds_per_model = rpm,
    n_estimators = 188, split_size = 960, learning_rate = 0.001,
    early_stopping_rounds = 16, mse_weight = 0.2, dtw_weight = 0.8, data_beg = 1000, data_end = 4000,
    batches = 5, min_bandpass_freq = 0.7, max_bandpass_freq = 4.0, bandpass_order = 4,
    predicted_peaks_prominence = 0.28,
    true_peaks_prominence = 0.322741927274642,
    max_depth = 6, max_bin = 235, num_feats_per_channel = 8, skip_amount = 12, collect = True
)
# Out:
# Number of samples in dataset: 34968
#
#
# On batch 1 of 5:
# [0]	train-rmse:0.79475	train-hr_err:24.04237	test-rmse:0.87105	test-hr_err:30.02595
# [5]	train-rmse:0.79766	train-hr_err:24.06602	test-rmse:0.87250	test-hr_err:30.02595
# [10]	train-rmse:0.80051	train-hr_err:29.18056	test-rmse:0.87425	test-hr_err:29.90439
# [15]	train-rmse:0.80336	train-hr_err:21.23306	test-rmse:0.87608	test-hr_err:30.25510
# [20]	train-rmse:0.80625	train-hr_err:29.59773	test-rmse:0.87782	test-hr_err:29.81337
# [25]	train-rmse:0.80916	train-hr_err:23.95244	test-rmse:0.87955	test-hr_err:28.17920
# [30]	train-rmse:0.81210	train-hr_err:42.50947	test-rmse:0.88130	test-hr_err:25.46732
# [35]	train-rmse:0.81507	train-hr_err:38.35692	test-rmse:0.88307	test-hr_err:26.18956
# [40]	train-rmse:0.81805	train-hr_err:38.02150	test-rmse:0.88483	test-hr_err:26.82572
# [45]	train-rmse:0.82106	train-hr_err:38.03884	test-rmse:0.88661	test-hr_err:27.26772
# [46]	train-rmse:0.82166	train-hr_err:38.03884	test-rmse:0.88697	test-hr_err:28.93006
# Fintuning...
# [0]	train-rmse:1.25052	train-hr_err:38.03884	test-rmse:0.88668	test-hr_err:28.43280
# [5]	train-rmse:1.24546	train-hr_err:42.18908	test-rmse:0.88344	test-hr_err:30.96782
# [7]	train-rmse:1.24344	train-hr_err:40.98473	test-rmse:0.88216	test-hr_err:30.24661
#
#
# On batch 2 of 5:
# [0]	train-rmse:0.89378	train-hr_err:18.64181	test-rmse:0.88207	test-hr_err:30.05686
# [5]	train-rmse:0.89779	train-hr_err:18.65249	test-rmse:0.88485	test-hr_err:27.45050
# [10]	train-rmse:0.90184	train-hr_err:17.78332	test-rmse:0.88767	test-hr_err:27.69967
# [15]	train-rmse:0.90590	train-hr_err:17.23532	test-rmse:0.89053	test-hr_err:27.41402
# [20]	train-rmse:0.90979	train-hr_err:17.58976	test-rmse:0.89336	test-hr_err:28.90236
# [23]	train-rmse:0.91206	train-hr_err:15.40102	test-rmse:0.89505	test-hr_err:26.91690
# Fintuning...
# [0]	train-rmse:1.31502	train-hr_err:13.15345	test-rmse:0.89494	test-hr_err:26.33120
# [5]	train-rmse:1.30947	train-hr_err:15.26766	test-rmse:0.89172	test-hr_err:25.49453
# [10]	train-rmse:1.30403	train-hr_err:16.53625	test-rmse:0.88866	test-hr_err:27.25171
# [13]	train-rmse:1.30081	train-hr_err:15.47255	test-rmse:0.88681	test-hr_err:26.09159
#
#
# On batch 3 of 5:
# [0]	train-rmse:0.87581	train-hr_err:16.50056	test-rmse:0.88723	test-hr_err:26.34466
# [5]	train-rmse:0.87902	train-hr_err:17.70317	test-rmse:0.88935	test-hr_err:24.40040
# [10]	train-rmse:0.88229	train-hr_err:20.02467	test-rmse:0.89150	test-hr_err:24.74966
# [15]	train-rmse:0.88559	train-hr_err:17.28780	test-rmse:0.89368	test-hr_err:24.47041
# [20]	train-rmse:0.88891	train-hr_err:17.25334	test-rmse:0.89590	test-hr_err:25.36670
# [22]	train-rmse:0.89024	train-hr_err:16.32398	test-rmse:0.89679	test-hr_err:26.08831
# Fintuning...
# [0]	train-rmse:1.31187	train-hr_err:16.49101	test-rmse:0.89611	test-hr_err:25.40518
# [5]	train-rmse:1.30677	train-hr_err:17.39030	test-rmse:0.89275	test-hr_err:22.25791
# [10]	train-rmse:1.30170	train-hr_err:16.25286	test-rmse:0.88947	test-hr_err:21.55130
# [15]	train-rmse:1.29666	train-hr_err:17.50404	test-rmse:0.88626	test-hr_err:22.13921
# [20]	train-rmse:1.29165	train-hr_err:16.25286	test-rmse:0.88309	test-hr_err:24.84680
#
#
# On batch 4 of 5:
# [0]	train-rmse:0.93673	train-hr_err:32.45217	test-rmse:0.88298	test-hr_err:25.30347
# [5]	train-rmse:0.94088	train-hr_err:34.25899	test-rmse:0.88557	test-hr_err:26.53696
# [10]	train-rmse:0.94506	train-hr_err:33.88014	test-rmse:0.88819	test-hr_err:27.17960
# [15]	train-rmse:0.94926	train-hr_err:35.06233	test-rmse:0.89084	test-hr_err:27.76619
# [16]	train-rmse:0.95011	train-hr_err:33.23722	test-rmse:0.89137	test-hr_err:27.91366
# Fintuning...
# [0]	train-rmse:1.34780	train-hr_err:33.44932	test-rmse:0.89069	test-hr_err:27.50537
# [5]	train-rmse:1.34210	train-hr_err:34.08868	test-rmse:0.88734	test-hr_err:26.26074
# [10]	train-rmse:1.33640	train-hr_err:34.36247	test-rmse:0.88405	test-hr_err:26.26332
# [12]	train-rmse:1.33415	train-hr_err:34.36247	test-rmse:0.88272	test-hr_err:26.67484
#
#
# On batch 5 of 5:
# [0]	train-rmse:0.88338	train-hr_err:26.40103	test-rmse:0.88314	test-hr_err:26.26750
# [5]	train-rmse:0.88683	train-hr_err:26.09230	test-rmse:0.88528	test-hr_err:24.20857
# [10]	train-rmse:0.89028	train-hr_err:26.00815	test-rmse:0.88746	test-hr_err:23.74181
# [15]	train-rmse:0.89376	train-hr_err:25.17635	test-rmse:0.88968	test-hr_err:21.47604
# [20]	train-rmse:0.89724	train-hr_err:26.25131	test-rmse:0.89195	test-hr_err:22.77404
# [25]	train-rmse:0.90073	train-hr_err:26.98605	test-rmse:0.89426	test-hr_err:22.92257
# [30]	train-rmse:0.90425	train-hr_err:28.19970	test-rmse:0.89660	test-hr_err:23.43663
# [34]	train-rmse:0.90708	train-hr_err:29.33849	test-rmse:0.89850	test-hr_err:23.44957
# Fintuning...
# [0]	train-rmse:1.31537	train-hr_err:29.58266	test-rmse:0.89782	test-hr_err:23.44483
# [5]	train-rmse:1.31010	train-hr_err:26.03233	test-rmse:0.89444	test-hr_err:21.86892
# [10]	train-rmse:1.30487	train-hr_err:24.74165	test-rmse:0.89111	test-hr_err:22.46331
# [13]	train-rmse:1.30174	train-hr_err:25.46643	test-rmse:0.88913	test-hr_err:22.04716
# Finished training in 0:02:01.480212
# Number of samples in dataset: 34968
#
#
# On batch 1 of 5:
# [0]	train-rmse:0.71329	train-hr_err:29.59475	test-rmse:0.88051	test-hr_err:31.36417
# [5]	train-rmse:0.71718	train-hr_err:30.98192	test-rmse:0.88267	test-hr_err:31.32503
# [10]	train-rmse:0.72106	train-hr_err:32.42559	test-rmse:0.88489	test-hr_err:32.54980
# [15]	train-rmse:0.72496	train-hr_err:35.20040	test-rmse:0.88715	test-hr_err:32.62912
# [20]	train-rmse:0.72889	train-hr_err:35.20438	test-rmse:0.88945	test-hr_err:32.20508
# [22]	train-rmse:0.73048	train-hr_err:36.58567	test-rmse:0.89040	test-hr_err:31.61848
# Fintuning...
# [0]	train-rmse:1.17721	train-hr_err:35.21971	test-rmse:0.88976	test-hr_err:33.23087
# [5]	train-rmse:1.17185	train-hr_err:33.36597	test-rmse:0.88658	test-hr_err:34.99279
# [10]	train-rmse:1.16651	train-hr_err:26.33829	test-rmse:0.88344	test-hr_err:33.57091
# [15]	train-rmse:1.16121	train-hr_err:26.84697	test-rmse:0.88034	test-hr_err:33.76910
# [16]	train-rmse:1.16015	train-hr_err:29.20280	test-rmse:0.87973	test-hr_err:34.18808
#
#
# On batch 2 of 5:
# [0]	train-rmse:0.90009	train-hr_err:29.21844	test-rmse:0.88011	test-hr_err:35.33036
# [5]	train-rmse:0.90296	train-hr_err:26.60050	test-rmse:0.88206	test-hr_err:32.75957
# [10]	train-rmse:0.90586	train-hr_err:25.31714	test-rmse:0.88401	test-hr_err:31.26960
# [15]	train-rmse:0.90878	train-hr_err:26.64680	test-rmse:0.88599	test-hr_err:30.73973
# [20]	train-rmse:0.91171	train-hr_err:24.71700	test-rmse:0.88800	test-hr_err:31.51415
# [25]	train-rmse:0.91471	train-hr_err:24.88503	test-rmse:0.89003	test-hr_err:29.98793
# [29]	train-rmse:0.91712	train-hr_err:26.07259	test-rmse:0.89168	test-hr_err:31.81894
# Fintuning...
# [0]	train-rmse:1.29360	train-hr_err:24.74500	test-rmse:0.89153	test-hr_err:31.89180
# [5]	train-rmse:1.28891	train-hr_err:24.76952	test-rmse:0.88875	test-hr_err:31.33999
# [10]	train-rmse:1.28425	train-hr_err:22.51085	test-rmse:0.88600	test-hr_err:31.43912
# [12]	train-rmse:1.28240	train-hr_err:21.46737	test-rmse:0.88491	test-hr_err:31.84176
#
#
# On batch 3 of 5:
# [0]	train-rmse:0.83736	train-hr_err:24.53936	test-rmse:0.88538	test-hr_err:32.11897
# [5]	train-rmse:0.84115	train-hr_err:24.55435	test-rmse:0.88778	test-hr_err:32.42102
# [10]	train-rmse:0.84497	train-hr_err:19.86869	test-rmse:0.89024	test-hr_err:32.97586
# [15]	train-rmse:0.84881	train-hr_err:18.77405	test-rmse:0.89273	test-hr_err:31.33133
# [20]	train-rmse:0.85268	train-hr_err:22.30432	test-rmse:0.89524	test-hr_err:30.83357
# [25]	train-rmse:0.85657	train-hr_err:18.98278	test-rmse:0.89779	test-hr_err:29.95448
# [30]	train-rmse:0.86050	train-hr_err:19.06518	test-rmse:0.90036	test-hr_err:31.15717
# [35]	train-rmse:0.86433	train-hr_err:18.69838	test-rmse:0.90304	test-hr_err:31.12180
# [38]	train-rmse:0.86666	train-hr_err:17.53822	test-rmse:0.90463	test-hr_err:29.50104
# Fintuning...
# [0]	train-rmse:1.30024	train-hr_err:18.69602	test-rmse:0.90389	test-hr_err:29.89663
# [5]	train-rmse:1.29456	train-hr_err:18.69602	test-rmse:0.90023	test-hr_err:31.15220
# [8]	train-rmse:1.29117	train-hr_err:18.67612	test-rmse:0.89806	test-hr_err:31.41520
#
#
# On batch 4 of 5:
# [0]	train-rmse:1.02762	train-hr_err:23.90810	test-rmse:0.89842	test-hr_err:31.80318
# [5]	train-rmse:1.03129	train-hr_err:24.64458	test-rmse:0.90029	test-hr_err:31.46377
# [10]	train-rmse:1.03497	train-hr_err:25.94835	test-rmse:0.90219	test-hr_err:31.92635
# [15]	train-rmse:1.03849	train-hr_err:25.50027	test-rmse:0.90423	test-hr_err:32.53997
# [20]	train-rmse:1.04199	train-hr_err:23.16211	test-rmse:0.90624	test-hr_err:31.26786
# [21]	train-rmse:1.04269	train-hr_err:23.16211	test-rmse:0.90664	test-hr_err:30.88210
# Fintuning...
# [0]	train-rmse:1.42481	train-hr_err:22.29605	test-rmse:0.90637	test-hr_err:31.69117
# [5]	train-rmse:1.41928	train-hr_err:25.16955	test-rmse:0.90301	test-hr_err:32.47588
# [7]	train-rmse:1.41708	train-hr_err:21.77364	test-rmse:0.90168	test-hr_err:32.25001
#
#
# On batch 5 of 5:
# [0]	train-rmse:0.77773	train-hr_err:19.73041	test-rmse:0.90155	test-hr_err:32.15096
# [5]	train-rmse:0.78153	train-hr_err:20.85928	test-rmse:0.90423	test-hr_err:31.65872
# [10]	train-rmse:0.78536	train-hr_err:19.93354	test-rmse:0.90692	test-hr_err:32.30393
# [15]	train-rmse:0.78921	train-hr_err:15.91120	test-rmse:0.90960	test-hr_err:31.79862
# [20]	train-rmse:0.79311	train-hr_err:15.52675	test-rmse:0.91229	test-hr_err:30.23118
# [25]	train-rmse:0.79701	train-hr_err:16.33565	test-rmse:0.91502	test-hr_err:29.67674
# [30]	train-rmse:0.80088	train-hr_err:15.16964	test-rmse:0.91777	test-hr_err:30.80034
# [35]	train-rmse:0.80477	train-hr_err:11.85887	test-rmse:0.92059	test-hr_err:32.16504
# [37]	train-rmse:0.80634	train-hr_err:12.95672	test-rmse:0.92173	test-hr_err:30.97912
# Fintuning...
# [0]	train-rmse:1.28913	train-hr_err:12.99447	test-rmse:0.92153	test-hr_err:31.36651
# [5]	train-rmse:1.28338	train-hr_err:13.73150	test-rmse:0.91769	test-hr_err:33.05550
# [8]	train-rmse:1.27995	train-hr_err:14.83495	test-rmse:0.91540	test-hr_err:33.44718
# Finished training in 0:01:43.659922
# Number of samples in dataset: 34968
#
#
# On batch 1 of 5:
# [0]	train-rmse:1.04885	train-hr_err:12.90179	test-rmse:0.81167	test-hr_err:33.82846
# [5]	train-rmse:1.05181	train-hr_err:11.24089	test-rmse:0.81403	test-hr_err:33.82846
# [10]	train-rmse:1.05480	train-hr_err:14.03120	test-rmse:0.81644	test-hr_err:33.79589
# [15]	train-rmse:1.05781	train-hr_err:14.03120	test-rmse:0.81885	test-hr_err:33.16603
# [20]	train-rmse:1.06085	train-hr_err:14.03120	test-rmse:0.82112	test-hr_err:32.80971
# [25]	train-rmse:1.06390	train-hr_err:14.05244	test-rmse:0.82341	test-hr_err:31.06880
# [30]	train-rmse:1.06695	train-hr_err:12.37139	test-rmse:0.82572	test-hr_err:30.87065
# [35]	train-rmse:1.07001	train-hr_err:12.37139	test-rmse:0.82807	test-hr_err:29.10855
# [40]	train-rmse:1.07315	train-hr_err:15.32376	test-rmse:0.83043	test-hr_err:29.55747
# [45]	train-rmse:1.07637	train-hr_err:15.69895	test-rmse:0.83279	test-hr_err:30.89385
# [50]	train-rmse:1.07965	train-hr_err:14.41035	test-rmse:0.83516	test-hr_err:30.85148
# [51]	train-rmse:1.08032	train-hr_err:14.41035	test-rmse:0.83563	test-hr_err:30.87086
# Fintuning...
# [0]	train-rmse:1.44216	train-hr_err:14.61528	test-rmse:0.83488	test-hr_err:30.85148
# [5]	train-rmse:1.43704	train-hr_err:9.74437	test-rmse:0.83118	test-hr_err:28.18416
# [10]	train-rmse:1.43197	train-hr_err:12.42456	test-rmse:0.82752	test-hr_err:31.91414
# [11]	train-rmse:1.43095	train-hr_err:12.42456	test-rmse:0.82700	test-hr_err:31.89493
#
#
# On batch 2 of 5:
# [0]	train-rmse:1.02322	train-hr_err:30.93203	test-rmse:0.82744	test-hr_err:31.50264
# [5]	train-rmse:1.02664	train-hr_err:30.14627	test-rmse:0.82967	test-hr_err:30.16345
# [10]	train-rmse:1.03020	train-hr_err:31.31274	test-rmse:0.83200	test-hr_err:28.72549
# [15]	train-rmse:1.03379	train-hr_err:34.44239	test-rmse:0.83449	test-hr_err:33.34195
# [20]	train-rmse:1.03740	train-hr_err:35.58472	test-rmse:0.83704	test-hr_err:35.23211
# [25]	train-rmse:1.04102	train-hr_err:35.59357	test-rmse:0.83969	test-hr_err:33.50754
# [26]	train-rmse:1.04175	train-hr_err:35.59357	test-rmse:0.84022	test-hr_err:32.51306
# Fintuning...
# [0]	train-rmse:1.41709	train-hr_err:35.57859	test-rmse:0.84002	test-hr_err:32.10236
# [5]	train-rmse:1.41188	train-hr_err:35.57859	test-rmse:0.83634	test-hr_err:32.93448
# [7]	train-rmse:1.40980	train-hr_err:35.57859	test-rmse:0.83488	test-hr_err:32.48151
#
#
# On batch 3 of 5:
# [0]	train-rmse:0.86501	train-hr_err:29.10231	test-rmse:0.83449	test-hr_err:32.48672
# [5]	train-rmse:0.86786	train-hr_err:27.80829	test-rmse:0.83620	test-hr_err:31.47370
# [10]	train-rmse:0.87074	train-hr_err:27.83439	test-rmse:0.83793	test-hr_err:30.99178
# [15]	train-rmse:0.87366	train-hr_err:25.91258	test-rmse:0.83968	test-hr_err:32.46168
# [20]	train-rmse:0.87663	train-hr_err:26.73532	test-rmse:0.84147	test-hr_err:30.89891
# [23]	train-rmse:0.87843	train-hr_err:26.04701	test-rmse:0.84249	test-hr_err:31.11629
# Fintuning...
# [0]	train-rmse:1.30591	train-hr_err:25.99096	test-rmse:0.84219	test-hr_err:30.74187
# [5]	train-rmse:1.30077	train-hr_err:26.01843	test-rmse:0.83900	test-hr_err:31.10405
# [10]	train-rmse:1.29566	train-hr_err:25.24174	test-rmse:0.83586	test-hr_err:30.59332
# [15]	train-rmse:1.29058	train-hr_err:25.24174	test-rmse:0.83275	test-hr_err:27.80708
# [20]	train-rmse:1.28554	train-hr_err:26.41732	test-rmse:0.82968	test-hr_err:26.12088
# [25]	train-rmse:1.28052	train-hr_err:26.86551	test-rmse:0.82665	test-hr_err:25.74686
# [30]	train-rmse:1.27553	train-hr_err:26.85470	test-rmse:0.82365	test-hr_err:25.76458
# [35]	train-rmse:1.27057	train-hr_err:27.99214	test-rmse:0.82069	test-hr_err:23.80042
# [40]	train-rmse:1.26564	train-hr_err:26.79662	test-rmse:0.81777	test-hr_err:22.65177
# [45]	train-rmse:1.26074	train-hr_err:25.72660	test-rmse:0.81489	test-hr_err:22.82471
# [49]	train-rmse:1.25685	train-hr_err:24.12096	test-rmse:0.81260	test-hr_err:25.19697
#
#
# On batch 4 of 5:
# [0]	train-rmse:0.64906	train-hr_err:33.63241	test-rmse:0.81254	test-hr_err:25.55136
# [5]	train-rmse:0.65299	train-hr_err:33.63241	test-rmse:0.81507	test-hr_err:22.90132
# [10]	train-rmse:0.65696	train-hr_err:33.63241	test-rmse:0.81763	test-hr_err:22.46441
# [15]	train-rmse:0.66096	train-hr_err:33.63241	test-rmse:0.82024	test-hr_err:22.74157
# [20]	train-rmse:0.66499	train-hr_err:33.62210	test-rmse:0.82290	test-hr_err:22.74157
# [25]	train-rmse:0.66906	train-hr_err:36.16874	test-rmse:0.82558	test-hr_err:22.73569
# [30]	train-rmse:0.67318	train-hr_err:36.41087	test-rmse:0.82829	test-hr_err:22.06433
# [35]	train-rmse:0.67733	train-hr_err:35.56468	test-rmse:0.83115	test-hr_err:22.06965
# [40]	train-rmse:0.68151	train-hr_err:34.09903	test-rmse:0.83405	test-hr_err:21.91477
# [45]	train-rmse:0.68574	train-hr_err:32.63338	test-rmse:0.83699	test-hr_err:21.00092
# [50]	train-rmse:0.69000	train-hr_err:29.70209	test-rmse:0.83997	test-hr_err:23.49031
# [55]	train-rmse:0.69434	train-hr_err:28.65291	test-rmse:0.84300	test-hr_err:22.97542
# [60]	train-rmse:0.69871	train-hr_err:29.91440	test-rmse:0.84608	test-hr_err:22.31554
# [61]	train-rmse:0.69959	train-hr_err:29.91440	test-rmse:0.84670	test-hr_err:22.72867
# Fintuning...
# [0]	train-rmse:1.20239	train-hr_err:28.71186	test-rmse:0.84592	test-hr_err:22.31554
# [5]	train-rmse:1.19685	train-hr_err:28.69169	test-rmse:0.84207	test-hr_err:22.31613
# [10]	train-rmse:1.19134	train-hr_err:28.71186	test-rmse:0.83827	test-hr_err:21.07882
# [15]	train-rmse:1.18586	train-hr_err:25.75591	test-rmse:0.83450	test-hr_err:21.20330
#
#
# On batch 5 of 5:
# [0]	train-rmse:0.77107	train-hr_err:32.16854	test-rmse:0.83429	test-hr_err:21.18756
# [5]	train-rmse:0.77478	train-hr_err:32.45896	test-rmse:0.83697	test-hr_err:23.04797
# [10]	train-rmse:0.77846	train-hr_err:32.64314	test-rmse:0.83974	test-hr_err:22.02578
# [15]	train-rmse:0.78210	train-hr_err:31.92859	test-rmse:0.84270	test-hr_err:21.81875
# [16]	train-rmse:0.78284	train-hr_err:31.92859	test-rmse:0.84329	test-hr_err:21.82617
# Fintuning...
# [0]	train-rmse:1.23449	train-hr_err:31.86904	test-rmse:0.84258	test-hr_err:21.41795
# [5]	train-rmse:1.22913	train-hr_err:29.05900	test-rmse:0.83901	test-hr_err:22.37383
# [9]	train-rmse:1.22486	train-hr_err:27.76170	test-rmse:0.83617	test-hr_err:22.77279
# Finished training in 0:02:23.098920
# Number of samples in dataset: 34968
#
#
# On batch 1 of 5:
# [0]	train-rmse:0.74320	train-hr_err:28.95730	test-rmse:0.84481	test-hr_err:42.21416
# [5]	train-rmse:0.74685	train-hr_err:27.95633	test-rmse:0.84735	test-hr_err:30.66567
# [10]	train-rmse:0.75051	train-hr_err:28.85799	test-rmse:0.84991	test-hr_err:23.10350
# [15]	train-rmse:0.75419	train-hr_err:33.48559	test-rmse:0.85244	test-hr_err:28.12523
# [20]	train-rmse:0.75790	train-hr_err:39.93892	test-rmse:0.85501	test-hr_err:31.54379
# [22]	train-rmse:0.75939	train-hr_err:39.93892	test-rmse:0.85606	test-hr_err:28.77057
# Fintuning...
# [0]	train-rmse:1.18360	train-hr_err:39.93892	test-rmse:0.85592	test-hr_err:28.09967
# [5]	train-rmse:1.17846	train-hr_err:34.34627	test-rmse:0.85258	test-hr_err:28.54954
# [10]	train-rmse:1.17335	train-hr_err:33.01431	test-rmse:0.84927	test-hr_err:27.31561
# [15]	train-rmse:1.16827	train-hr_err:30.91901	test-rmse:0.84601	test-hr_err:22.98976
# [20]	train-rmse:1.16321	train-hr_err:26.70578	test-rmse:0.84280	test-hr_err:28.69727
# [23]	train-rmse:1.16019	train-hr_err:28.30729	test-rmse:0.84088	test-hr_err:28.75102
#
#
# On batch 2 of 5:
# [0]	train-rmse:0.78750	train-hr_err:36.46375	test-rmse:0.84132	test-hr_err:30.09425
# [5]	train-rmse:0.79036	train-hr_err:33.92990	test-rmse:0.84356	test-hr_err:27.45093
# [10]	train-rmse:0.79324	train-hr_err:24.58080	test-rmse:0.84581	test-hr_err:21.11595
# [15]	train-rmse:0.79614	train-hr_err:19.02385	test-rmse:0.84810	test-hr_err:21.66580
# [20]	train-rmse:0.79907	train-hr_err:17.16247	test-rmse:0.85042	test-hr_err:22.68242
# [25]	train-rmse:0.80202	train-hr_err:16.14213	test-rmse:0.85277	test-hr_err:21.01293
# [30]	train-rmse:0.80499	train-hr_err:14.99825	test-rmse:0.85515	test-hr_err:22.88166
# Fintuning...
# [0]	train-rmse:1.19772	train-hr_err:15.02878	test-rmse:0.85447	test-hr_err:22.46045
# [5]	train-rmse:1.19288	train-hr_err:16.79190	test-rmse:0.85111	test-hr_err:22.15827
# [10]	train-rmse:1.18807	train-hr_err:19.96774	test-rmse:0.84776	test-hr_err:22.97719
# [14]	train-rmse:1.18425	train-hr_err:19.70294	test-rmse:0.84513	test-hr_err:23.28001
#
#
# On batch 3 of 5:
# [0]	train-rmse:1.10720	train-hr_err:22.89866	test-rmse:0.84551	test-hr_err:23.74985
# [5]	train-rmse:1.11005	train-hr_err:25.25592	test-rmse:0.84744	test-hr_err:21.46360
# [10]	train-rmse:1.11304	train-hr_err:25.69432	test-rmse:0.84931	test-hr_err:21.54202
# [15]	train-rmse:1.11625	train-hr_err:24.71203	test-rmse:0.85115	test-hr_err:20.88832
# [20]	train-rmse:1.11947	train-hr_err:21.35010	test-rmse:0.85294	test-hr_err:21.70652
# [25]	train-rmse:1.12269	train-hr_err:16.55880	test-rmse:0.85475	test-hr_err:20.58563
# [30]	train-rmse:1.12593	train-hr_err:15.86264	test-rmse:0.85655	test-hr_err:22.17073
# [35]	train-rmse:1.12917	train-hr_err:14.32466	test-rmse:0.85838	test-hr_err:23.29458
# [40]	train-rmse:1.13246	train-hr_err:10.74855	test-rmse:0.86034	test-hr_err:23.88092
# Fintuning...
# [0]	train-rmse:1.46115	train-hr_err:8.00214	test-rmse:0.85965	test-hr_err:23.93153
# [5]	train-rmse:1.45612	train-hr_err:10.73417	test-rmse:0.85622	test-hr_err:24.24035
# [10]	train-rmse:1.45112	train-hr_err:12.08201	test-rmse:0.85284	test-hr_err:22.28919
# [15]	train-rmse:1.44616	train-hr_err:17.11540	test-rmse:0.84952	test-hr_err:22.39261
# [20]	train-rmse:1.44122	train-hr_err:16.68884	test-rmse:0.84624	test-hr_err:22.03054
#
#
# On batch 4 of 5:
# [0]	train-rmse:0.92379	train-hr_err:13.58425	test-rmse:0.84675	test-hr_err:22.21571
# [5]	train-rmse:0.92715	train-hr_err:10.38794	test-rmse:0.84930	test-hr_err:22.63650
# [10]	train-rmse:0.93051	train-hr_err:8.68812	test-rmse:0.85183	test-hr_err:22.59759
# [15]	train-rmse:0.93388	train-hr_err:9.77612	test-rmse:0.85441	test-hr_err:23.60831
# [19]	train-rmse:0.93658	train-hr_err:9.79766	test-rmse:0.85652	test-hr_err:24.40483
# Fintuning...
# [0]	train-rmse:1.30308	train-hr_err:9.78138	test-rmse:0.85585	test-hr_err:24.40870
# [5]	train-rmse:1.29820	train-hr_err:10.85491	test-rmse:0.85252	test-hr_err:24.57295
# [9]	train-rmse:1.29432	train-hr_err:9.17092	test-rmse:0.84988	test-hr_err:24.23841
#
#
# On batch 5 of 5:
# [0]	train-rmse:0.80668	train-hr_err:15.36119	test-rmse:0.85037	test-hr_err:24.23841
# [5]	train-rmse:0.81006	train-hr_err:15.90118	test-rmse:0.85281	test-hr_err:23.92203
# [10]	train-rmse:0.81346	train-hr_err:16.62713	test-rmse:0.85527	test-hr_err:23.05047
# [15]	train-rmse:0.81690	train-hr_err:15.46913	test-rmse:0.85781	test-hr_err:20.76929
# [20]	train-rmse:0.82038	train-hr_err:16.82944	test-rmse:0.86038	test-hr_err:19.99894
# [25]	train-rmse:0.82389	train-hr_err:19.31139	test-rmse:0.86304	test-hr_err:20.03588
# [30]	train-rmse:0.82742	train-hr_err:19.31139	test-rmse:0.86573	test-hr_err:19.97523
# [35]	train-rmse:0.83098	train-hr_err:19.83965	test-rmse:0.86839	test-hr_err:19.50684
# [40]	train-rmse:0.83455	train-hr_err:20.88515	test-rmse:0.87106	test-hr_err:20.55921
# [45]	train-rmse:0.83815	train-hr_err:21.94242	test-rmse:0.87377	test-hr_err:21.69614
# [50]	train-rmse:0.84177	train-hr_err:19.82544	test-rmse:0.87651	test-hr_err:19.58192
# [55]	train-rmse:0.84542	train-hr_err:20.86216	test-rmse:0.87928	test-hr_err:18.51819
# [60]	train-rmse:0.84909	train-hr_err:19.77183	test-rmse:0.88208	test-hr_err:17.12938
# [65]	train-rmse:0.85277	train-hr_err:20.83646	test-rmse:0.88493	test-hr_err:17.66519
# [70]	train-rmse:0.85648	train-hr_err:19.04812	test-rmse:0.88784	test-hr_err:17.65192
# [75]	train-rmse:0.86022	train-hr_err:18.74017	test-rmse:0.89079	test-hr_err:17.89664
# [76]	train-rmse:0.86098	train-hr_err:18.74017	test-rmse:0.89139	test-hr_err:17.53065
# Fintuning...
# [0]	train-rmse:1.33255	train-hr_err:18.78998	test-rmse:0.89044	test-hr_err:17.53438
# [5]	train-rmse:1.32689	train-hr_err:19.93831	test-rmse:0.88574	test-hr_err:17.11849
# [10]	train-rmse:1.32126	train-hr_err:19.74496	test-rmse:0.88113	test-hr_err:16.26053
# [15]	train-rmse:1.31568	train-hr_err:19.74496	test-rmse:0.87659	test-hr_err:17.20900
# [17]	train-rmse:1.31346	train-hr_err:18.66510	test-rmse:0.87479	test-hr_err:17.20900
# Finished training in 0:02:29.249433
# Number of samples in dataset: 34968
#
#
# On batch 1 of 5:
# [0]	train-rmse:0.97803	train-hr_err:43.64153	test-rmse:0.87991	test-hr_err:29.18325
# [5]	train-rmse:0.98046	train-hr_err:43.64153	test-rmse:0.88183	test-hr_err:29.18325
# [10]	train-rmse:0.98291	train-hr_err:43.64153	test-rmse:0.88377	test-hr_err:29.18325
# [15]	train-rmse:0.98538	train-hr_err:43.64153	test-rmse:0.88573	test-hr_err:29.18325
# Fintuning...
# [0]	train-rmse:1.32967	train-hr_err:43.64153	test-rmse:0.88552	test-hr_err:29.80783
# [5]	train-rmse:1.32514	train-hr_err:39.19084	test-rmse:0.88251	test-hr_err:26.17974
# [10]	train-rmse:1.32061	train-hr_err:34.93095	test-rmse:0.87947	test-hr_err:16.20623
# [15]	train-rmse:1.31612	train-hr_err:34.09658	test-rmse:0.87646	test-hr_err:21.77698
# [20]	train-rmse:1.31166	train-hr_err:26.69737	test-rmse:0.87349	test-hr_err:19.26109
#
#
# On batch 2 of 5:
# [0]	train-rmse:0.74546	train-hr_err:13.86777	test-rmse:0.87335	test-hr_err:23.91567
# [5]	train-rmse:0.74875	train-hr_err:15.71038	test-rmse:0.87555	test-hr_err:22.26238
# [10]	train-rmse:0.75207	train-hr_err:19.93695	test-rmse:0.87778	test-hr_err:25.71800
# [15]	train-rmse:0.75541	train-hr_err:19.64470	test-rmse:0.88004	test-hr_err:29.70825
# [19]	train-rmse:0.75811	train-hr_err:22.14456	test-rmse:0.88186	test-hr_err:34.73100
# Fintuning...
# [0]	train-rmse:1.15995	train-hr_err:21.03153	test-rmse:0.88124	test-hr_err:34.30837
# [5]	train-rmse:1.15511	train-hr_err:20.98277	test-rmse:0.87818	test-hr_err:32.11640
# [10]	train-rmse:1.15029	train-hr_err:17.37788	test-rmse:0.87516	test-hr_err:31.92040
# [15]	train-rmse:1.14551	train-hr_err:18.34788	test-rmse:0.87218	test-hr_err:32.78260
# [16]	train-rmse:1.14455	train-hr_err:19.56925	test-rmse:0.87159	test-hr_err:32.41033
#
#
# On batch 3 of 5:
# [0]	train-rmse:0.78413	train-hr_err:37.20679	test-rmse:0.87203	test-hr_err:31.55161
# [5]	train-rmse:0.78800	train-hr_err:34.18785	test-rmse:0.87434	test-hr_err:27.69211
# [10]	train-rmse:0.79187	train-hr_err:30.88983	test-rmse:0.87666	test-hr_err:25.86651
# [15]	train-rmse:0.79578	train-hr_err:29.81446	test-rmse:0.87891	test-hr_err:24.17804
# [20]	train-rmse:0.79971	train-hr_err:27.27776	test-rmse:0.88121	test-hr_err:24.26249
# [25]	train-rmse:0.80364	train-hr_err:26.27693	test-rmse:0.88365	test-hr_err:23.71312
# [30]	train-rmse:0.80750	train-hr_err:22.66440	test-rmse:0.88630	test-hr_err:25.74576
# [32]	train-rmse:0.80905	train-hr_err:27.14855	test-rmse:0.88736	test-hr_err:26.13536
# Fintuning...
# [0]	train-rmse:1.20828	train-hr_err:25.55208	test-rmse:0.88674	test-hr_err:25.65584
# [5]	train-rmse:1.20299	train-hr_err:26.67889	test-rmse:0.88365	test-hr_err:25.23239
# [10]	train-rmse:1.19773	train-hr_err:25.82757	test-rmse:0.88060	test-hr_err:25.17759
# [15]	train-rmse:1.19250	train-hr_err:28.00383	test-rmse:0.87760	test-hr_err:22.20456
# [20]	train-rmse:1.18729	train-hr_err:30.18283	test-rmse:0.87466	test-hr_err:21.13968
# [25]	train-rmse:1.18211	train-hr_err:25.37533	test-rmse:0.87179	test-hr_err:21.51905
# [29]	train-rmse:1.17799	train-hr_err:25.65870	test-rmse:0.86953	test-hr_err:21.54199
#
#
# On batch 4 of 5:
# [0]	train-rmse:0.80403	train-hr_err:22.61754	test-rmse:0.87001	test-hr_err:20.98575
# [5]	train-rmse:0.80772	train-hr_err:19.52625	test-rmse:0.87243	test-hr_err:22.97059
# [10]	train-rmse:0.81144	train-hr_err:17.18177	test-rmse:0.87489	test-hr_err:21.59654
# [15]	train-rmse:0.81519	train-hr_err:15.24651	test-rmse:0.87738	test-hr_err:22.35431
# Fintuning...
# [0]	train-rmse:1.20092	train-hr_err:15.40349	test-rmse:0.87723	test-hr_err:21.57807
# [5]	train-rmse:1.19597	train-hr_err:14.15716	test-rmse:0.87395	test-hr_err:22.22524
# [10]	train-rmse:1.19105	train-hr_err:16.57195	test-rmse:0.87071	test-hr_err:20.99654
# [15]	train-rmse:1.18616	train-hr_err:15.09622	test-rmse:0.86753	test-hr_err:22.39663
# [16]	train-rmse:1.18519	train-hr_err:15.09622	test-rmse:0.86690	test-hr_err:22.77720
#
#
# On batch 5 of 5:
# [0]	train-rmse:0.89047	train-hr_err:28.08059	test-rmse:0.86658	test-hr_err:23.59700
# [5]	train-rmse:0.89335	train-hr_err:24.29504	test-rmse:0.86812	test-hr_err:18.66131
# [10]	train-rmse:0.89624	train-hr_err:24.04785	test-rmse:0.86970	test-hr_err:21.57975
# [15]	train-rmse:0.89914	train-hr_err:23.82683	test-rmse:0.87128	test-hr_err:23.71134
# [20]	train-rmse:0.90204	train-hr_err:25.43658	test-rmse:0.87283	test-hr_err:23.95750
# [21]	train-rmse:0.90266	train-hr_err:25.43658	test-rmse:0.87316	test-hr_err:24.36819
# Fintuning...
# [0]	train-rmse:1.24280	train-hr_err:25.43208	test-rmse:0.87257	test-hr_err:24.34929
# [5]	train-rmse:1.23814	train-hr_err:24.33274	test-rmse:0.86961	test-hr_err:23.98436
# [10]	train-rmse:1.23351	train-hr_err:26.17292	test-rmse:0.86670	test-hr_err:24.17398
# [11]	train-rmse:1.23259	train-hr_err:26.14992	test-rmse:0.86612	test-hr_err:25.00397
# Finished training in 0:02:15.245878
# Number of samples in dataset: 34968
#
#
# On batch 1 of 5:
# [0]	train-rmse:0.88056	train-hr_err:37.15353	test-rmse:0.83316	test-hr_err:33.10275
# [5]	train-rmse:0.88353	train-hr_err:38.51523	test-rmse:0.83494	test-hr_err:33.71519
# [10]	train-rmse:0.88652	train-hr_err:38.51523	test-rmse:0.83674	test-hr_err:32.67651
# [15]	train-rmse:0.88952	train-hr_err:36.67388	test-rmse:0.83870	test-hr_err:28.53588
# [20]	train-rmse:0.89254	train-hr_err:36.65302	test-rmse:0.84074	test-hr_err:30.25291
# [25]	train-rmse:0.89557	train-hr_err:34.40763	test-rmse:0.84283	test-hr_err:29.65204
# [30]	train-rmse:0.89860	train-hr_err:31.93851	test-rmse:0.84497	test-hr_err:30.25309
# [31]	train-rmse:0.89921	train-hr_err:31.93851	test-rmse:0.84540	test-hr_err:30.25309
# Fintuning...
# [0]	train-rmse:1.27179	train-hr_err:31.17355	test-rmse:0.84480	test-hr_err:30.25309
# [5]	train-rmse:1.26705	train-hr_err:32.73257	test-rmse:0.84184	test-hr_err:31.42616
# [8]	train-rmse:1.26421	train-hr_err:31.38626	test-rmse:0.84008	test-hr_err:30.69331
#
#
# On batch 2 of 5:
# [0]	train-rmse:1.03083	train-hr_err:16.67196	test-rmse:0.84059	test-hr_err:30.78060
# [5]	train-rmse:1.03433	train-hr_err:15.53006	test-rmse:0.84317	test-hr_err:35.03908
# [10]	train-rmse:1.03784	train-hr_err:17.63060	test-rmse:0.84582	test-hr_err:35.23518
# [15]	train-rmse:1.04135	train-hr_err:16.57225	test-rmse:0.84854	test-hr_err:32.78455
# [16]	train-rmse:1.04205	train-hr_err:15.21621	test-rmse:0.84908	test-hr_err:31.46329
# Fintuning...
# [0]	train-rmse:1.39179	train-hr_err:16.59242	test-rmse:0.84836	test-hr_err:31.84150
# [5]	train-rmse:1.38631	train-hr_err:19.84373	test-rmse:0.84480	test-hr_err:33.74620
# [10]	train-rmse:1.38088	train-hr_err:17.91682	test-rmse:0.84130	test-hr_err:32.58364
# [15]	train-rmse:1.37549	train-hr_err:22.09113	test-rmse:0.83785	test-hr_err:32.07348
# [17]	train-rmse:1.37334	train-hr_err:22.29875	test-rmse:0.83649	test-hr_err:32.26735
#
#
# On batch 3 of 5:
# [0]	train-rmse:0.88446	train-hr_err:19.15622	test-rmse:0.83714	test-hr_err:31.97219
# [5]	train-rmse:0.88840	train-hr_err:15.04075	test-rmse:0.84045	test-hr_err:32.36265
# [10]	train-rmse:0.89236	train-hr_err:18.77701	test-rmse:0.84383	test-hr_err:31.94931
# [15]	train-rmse:0.89634	train-hr_err:19.49571	test-rmse:0.84728	test-hr_err:33.57801
# [19]	train-rmse:0.89955	train-hr_err:16.35059	test-rmse:0.85009	test-hr_err:33.45873
# Fintuning...
# [0]	train-rmse:1.28691	train-hr_err:23.21726	test-rmse:0.84926	test-hr_err:33.28834
# [5]	train-rmse:1.28141	train-hr_err:17.06250	test-rmse:0.84517	test-hr_err:32.35477
# [10]	train-rmse:1.27595	train-hr_err:10.76068	test-rmse:0.84127	test-hr_err:31.48647
# [15]	train-rmse:1.27051	train-hr_err:11.09993	test-rmse:0.83764	test-hr_err:31.59514
# [16]	train-rmse:1.26943	train-hr_err:11.09993	test-rmse:0.83696	test-hr_err:31.59514
#
#
# On batch 4 of 5:
# [0]	train-rmse:1.00851	train-hr_err:31.87195	test-rmse:0.83664	test-hr_err:30.67726
# [5]	train-rmse:1.01202	train-hr_err:30.66001	test-rmse:0.83848	test-hr_err:30.24234
# [10]	train-rmse:1.01549	train-hr_err:25.37747	test-rmse:0.84033	test-hr_err:28.79319
# [15]	train-rmse:1.01899	train-hr_err:27.56161	test-rmse:0.84222	test-hr_err:25.64200
# [20]	train-rmse:1.02261	train-hr_err:25.65900	test-rmse:0.84430	test-hr_err:25.08653
# [25]	train-rmse:1.02627	train-hr_err:20.80752	test-rmse:0.84646	test-hr_err:27.80748
# [30]	train-rmse:1.02994	train-hr_err:18.30587	test-rmse:0.84865	test-hr_err:28.01886
# [35]	train-rmse:1.03362	train-hr_err:17.17353	test-rmse:0.85087	test-hr_err:26.27037
# [36]	train-rmse:1.03436	train-hr_err:16.08014	test-rmse:0.85132	test-hr_err:26.27037
# Fintuning...
# [0]	train-rmse:1.39819	train-hr_err:14.53114	test-rmse:0.85104	test-hr_err:27.13822
# [5]	train-rmse:1.39273	train-hr_err:15.65658	test-rmse:0.84741	test-hr_err:26.42217
# [10]	train-rmse:1.38731	train-hr_err:16.92913	test-rmse:0.84383	test-hr_err:25.10277
# [15]	train-rmse:1.38190	train-hr_err:18.21763	test-rmse:0.84030	test-hr_err:25.73374
# [17]	train-rmse:1.37975	train-hr_err:18.21763	test-rmse:0.83890	test-hr_err:26.59248
#
#
# On batch 5 of 5:
# [0]	train-rmse:0.66505	train-hr_err:28.01503	test-rmse:0.83941	test-hr_err:25.74390
# [5]	train-rmse:0.66889	train-hr_err:27.99208	test-rmse:0.84198	test-hr_err:24.11489
# [10]	train-rmse:0.67277	train-hr_err:28.01330	test-rmse:0.84460	test-hr_err:22.80085
# [15]	train-rmse:0.67669	train-hr_err:29.39205	test-rmse:0.84725	test-hr_err:23.31550
# [20]	train-rmse:0.68066	train-hr_err:30.56405	test-rmse:0.84993	test-hr_err:23.13764
# [25]	train-rmse:0.68466	train-hr_err:30.63132	test-rmse:0.85265	test-hr_err:24.44180
# [27]	train-rmse:0.68628	train-hr_err:29.30961	test-rmse:0.85376	test-hr_err:24.48851
# Fintuning...
# [0]	train-rmse:1.16200	train-hr_err:29.37618	test-rmse:0.85304	test-hr_err:24.55357
# [5]	train-rmse:1.15673	train-hr_err:29.37618	test-rmse:0.84947	test-hr_err:26.05172
# [8]	train-rmse:1.15358	train-hr_err:29.40503	test-rmse:0.84735	test-hr_err:24.89777
# Finished training in 0:02:19.902678
# Number of samples in dataset: 34968
#
#
# On batch 1 of 5:
# [0]	train-rmse:0.74215	train-hr_err:35.98017	test-rmse:0.86757	test-hr_err:35.95071
# [5]	train-rmse:0.74596	train-hr_err:35.98017	test-rmse:0.87012	test-hr_err:36.01534
# [10]	train-rmse:0.74979	train-hr_err:35.98017	test-rmse:0.87271	test-hr_err:36.08175
# [15]	train-rmse:0.75365	train-hr_err:34.90754	test-rmse:0.87528	test-hr_err:36.50079
# [16]	train-rmse:0.75442	train-hr_err:33.83492	test-rmse:0.87579	test-hr_err:37.07307
# Fintuning...
# [0]	train-rmse:1.17370	train-hr_err:33.83492	test-rmse:0.87517	test-hr_err:41.20625
# [5]	train-rmse:1.16854	train-hr_err:5.84021	test-rmse:0.87207	test-hr_err:39.16266
# [10]	train-rmse:1.16340	train-hr_err:8.06337	test-rmse:0.86899	test-hr_err:43.41713
# [12]	train-rmse:1.16136	train-hr_err:9.07328	test-rmse:0.86778	test-hr_err:44.09532
#
#
# On batch 2 of 5:
# [0]	train-rmse:0.89731	train-hr_err:26.35319	test-rmse:0.86766	test-hr_err:43.65781
# [5]	train-rmse:0.90096	train-hr_err:24.50049	test-rmse:0.87015	test-hr_err:31.08380
# [10]	train-rmse:0.90463	train-hr_err:23.77972	test-rmse:0.87270	test-hr_err:32.55862
# [15]	train-rmse:0.90832	train-hr_err:25.14332	test-rmse:0.87533	test-hr_err:30.23335
# [19]	train-rmse:0.91129	train-hr_err:18.03434	test-rmse:0.87747	test-hr_err:32.63666
# Fintuning...
# [0]	train-rmse:1.28249	train-hr_err:18.01497	test-rmse:0.87728	test-hr_err:32.70796
# [5]	train-rmse:1.27739	train-hr_err:23.47226	test-rmse:0.87404	test-hr_err:31.61926
# [10]	train-rmse:1.27233	train-hr_err:20.27557	test-rmse:0.87084	test-hr_err:27.98164
# [15]	train-rmse:1.26730	train-hr_err:13.00515	test-rmse:0.86769	test-hr_err:27.97444
# [19]	train-rmse:1.26329	train-hr_err:13.02091	test-rmse:0.86520	test-hr_err:28.11776
#
#
# On batch 3 of 5:
# [0]	train-rmse:0.62687	train-hr_err:20.52734	test-rmse:0.86498	test-hr_err:28.46525
# [5]	train-rmse:0.63071	train-hr_err:19.57399	test-rmse:0.86713	test-hr_err:28.26289
# [10]	train-rmse:0.63458	train-hr_err:23.76547	test-rmse:0.86934	test-hr_err:27.97208
# [15]	train-rmse:0.63849	train-hr_err:23.51282	test-rmse:0.87161	test-hr_err:25.84812
# [20]	train-rmse:0.64242	train-hr_err:18.05371	test-rmse:0.87391	test-hr_err:24.88310
# [25]	train-rmse:0.64639	train-hr_err:19.42673	test-rmse:0.87622	test-hr_err:25.03974
# [30]	train-rmse:0.65039	train-hr_err:22.76326	test-rmse:0.87853	test-hr_err:24.69355
# [35]	train-rmse:0.65443	train-hr_err:21.69602	test-rmse:0.88087	test-hr_err:25.27094
# [40]	train-rmse:0.65849	train-hr_err:26.40551	test-rmse:0.88313	test-hr_err:23.47794
# [45]	train-rmse:0.66259	train-hr_err:26.95032	test-rmse:0.88543	test-hr_err:24.90036
# [50]	train-rmse:0.66671	train-hr_err:28.56192	test-rmse:0.88776	test-hr_err:25.90037
# [54]	train-rmse:0.67003	train-hr_err:33.35679	test-rmse:0.88965	test-hr_err:25.69027
# Fintuning...
# [0]	train-rmse:1.15490	train-hr_err:33.37207	test-rmse:0.88950	test-hr_err:25.87824
# [5]	train-rmse:1.14953	train-hr_err:32.66155	test-rmse:0.88639	test-hr_err:25.57878
# [10]	train-rmse:1.14419	train-hr_err:23.35846	test-rmse:0.88329	test-hr_err:25.22087
# [15]	train-rmse:1.13888	train-hr_err:24.25894	test-rmse:0.88019	test-hr_err:25.35448
#
#
# On batch 4 of 5:
# [0]	train-rmse:1.11305	train-hr_err:19.05072	test-rmse:0.88068	test-hr_err:28.02079
# [5]	train-rmse:1.11716	train-hr_err:17.04959	test-rmse:0.88339	test-hr_err:29.27489
# [10]	train-rmse:1.12129	train-hr_err:17.09671	test-rmse:0.88616	test-hr_err:26.15995
# [15]	train-rmse:1.12543	train-hr_err:13.18362	test-rmse:0.88878	test-hr_err:24.61387
# [20]	train-rmse:1.12960	train-hr_err:14.60790	test-rmse:0.89145	test-hr_err:26.95179
# [25]	train-rmse:1.13379	train-hr_err:13.27141	test-rmse:0.89414	test-hr_err:27.68728
# [26]	train-rmse:1.13464	train-hr_err:13.27141	test-rmse:0.89469	test-hr_err:27.20054
# Fintuning...
# [0]	train-rmse:1.50722	train-hr_err:13.62467	test-rmse:0.89437	test-hr_err:27.37309
# [5]	train-rmse:1.50161	train-hr_err:12.16643	test-rmse:0.89021	test-hr_err:28.44066
# [7]	train-rmse:1.49938	train-hr_err:11.01622	test-rmse:0.88856	test-hr_err:28.95779
#
#
# On batch 5 of 5:
# [0]	train-rmse:0.97025	train-hr_err:26.21592	test-rmse:0.88826	test-hr_err:29.46850
# [5]	train-rmse:0.97307	train-hr_err:27.34794	test-rmse:0.89091	test-hr_err:29.05385
# [10]	train-rmse:0.97591	train-hr_err:28.08954	test-rmse:0.89360	test-hr_err:29.54102
# [15]	train-rmse:0.97874	train-hr_err:28.73206	test-rmse:0.89632	test-hr_err:30.10668
# [18]	train-rmse:0.98041	train-hr_err:27.62650	test-rmse:0.89796	test-hr_err:30.61510
# Fintuning...
# [0]	train-rmse:1.36172	train-hr_err:25.68631	test-rmse:0.89763	test-hr_err:31.02693
# [5]	train-rmse:1.35678	train-hr_err:25.72866	test-rmse:0.89330	test-hr_err:32.18154
# [8]	train-rmse:1.35382	train-hr_err:23.99356	test-rmse:0.89072	test-hr_err:32.56610
# Finished training in 0:02:20.108274
# Number of samples in dataset: 34968
#
#
# On batch 1 of 5:
# [0]	train-rmse:0.83544	train-hr_err:12.82666	test-rmse:0.86853	test-hr_err:27.69862
# [5]	train-rmse:0.83897	train-hr_err:12.82666	test-rmse:0.87057	test-hr_err:30.19687
# [10]	train-rmse:0.84252	train-hr_err:16.10598	test-rmse:0.87266	test-hr_err:30.29084
# [15]	train-rmse:0.84604	train-hr_err:12.49470	test-rmse:0.87489	test-hr_err:30.14614
# [20]	train-rmse:0.84959	train-hr_err:11.40255	test-rmse:0.87716	test-hr_err:30.91780
# Fintuning...
# [0]	train-rmse:1.25686	train-hr_err:11.38140	test-rmse:0.87656	test-hr_err:30.33386
# [5]	train-rmse:1.25168	train-hr_err:10.15162	test-rmse:0.87361	test-hr_err:27.81761
# [10]	train-rmse:1.24653	train-hr_err:15.46240	test-rmse:0.87069	test-hr_err:25.57980
# [15]	train-rmse:1.24140	train-hr_err:12.19161	test-rmse:0.86781	test-hr_err:26.87824
# [18]	train-rmse:1.23833	train-hr_err:11.20841	test-rmse:0.86611	test-hr_err:31.70150
#
#
# On batch 2 of 5:
# [0]	train-rmse:0.72644	train-hr_err:19.62497	test-rmse:0.86661	test-hr_err:31.40272
# [5]	train-rmse:0.73080	train-hr_err:16.43146	test-rmse:0.86914	test-hr_err:30.66448
# [10]	train-rmse:0.73519	train-hr_err:9.90898	test-rmse:0.87170	test-hr_err:28.16286
# [15]	train-rmse:0.73960	train-hr_err:8.83599	test-rmse:0.87430	test-hr_err:29.33631
# [20]	train-rmse:0.74405	train-hr_err:7.71655	test-rmse:0.87694	test-hr_err:31.21882
# [25]	train-rmse:0.74853	train-hr_err:6.61326	test-rmse:0.87962	test-hr_err:31.13817
# [28]	train-rmse:0.75123	train-hr_err:5.64804	test-rmse:0.88125	test-hr_err:31.28705
# Fintuning...
# [0]	train-rmse:1.20659	train-hr_err:5.66904	test-rmse:0.88112	test-hr_err:31.70663
# [5]	train-rmse:1.20102	train-hr_err:5.62539	test-rmse:0.87778	test-hr_err:32.46794
# [10]	train-rmse:1.19548	train-hr_err:6.36361	test-rmse:0.87448	test-hr_err:31.23433
# [15]	train-rmse:1.18997	train-hr_err:6.18485	test-rmse:0.87121	test-hr_err:32.58009
# [18]	train-rmse:1.18667	train-hr_err:7.31494	test-rmse:0.86927	test-hr_err:32.48227
#
#
# On batch 3 of 5:
# [0]	train-rmse:0.82727	train-hr_err:22.71511	test-rmse:0.86897	test-hr_err:32.36895
# [5]	train-rmse:0.83069	train-hr_err:23.85447	test-rmse:0.87077	test-hr_err:31.57552
# [10]	train-rmse:0.83414	train-hr_err:22.22319	test-rmse:0.87269	test-hr_err:30.58455
# [15]	train-rmse:0.83759	train-hr_err:20.48646	test-rmse:0.87456	test-hr_err:32.67304
# [20]	train-rmse:0.84101	train-hr_err:23.85978	test-rmse:0.87644	test-hr_err:31.87663
# [25]	train-rmse:0.84444	train-hr_err:21.63249	test-rmse:0.87830	test-hr_err:31.96243
# Fintuning...
# [0]	train-rmse:1.23942	train-hr_err:22.68995	test-rmse:0.87809	test-hr_err:31.92097
# [5]	train-rmse:1.23421	train-hr_err:20.50572	test-rmse:0.87518	test-hr_err:29.63630
# [10]	train-rmse:1.22902	train-hr_err:20.27585	test-rmse:0.87229	test-hr_err:30.51448
# [15]	train-rmse:1.22386	train-hr_err:19.79665	test-rmse:0.86944	test-hr_err:30.04830
# [16]	train-rmse:1.22283	train-hr_err:19.79665	test-rmse:0.86887	test-hr_err:29.62212
#
#
# On batch 4 of 5:
# [0]	train-rmse:0.97389	train-hr_err:28.89881	test-rmse:0.86932	test-hr_err:28.40921
# [5]	train-rmse:0.97705	train-hr_err:29.12880	test-rmse:0.87163	test-hr_err:26.33643
# [10]	train-rmse:0.98021	train-hr_err:30.87164	test-rmse:0.87399	test-hr_err:30.35476
# [15]	train-rmse:0.98340	train-hr_err:33.61506	test-rmse:0.87640	test-hr_err:34.40148
# [19]	train-rmse:0.98595	train-hr_err:38.03932	test-rmse:0.87838	test-hr_err:35.68533
# Fintuning...
# [0]	train-rmse:1.33437	train-hr_err:35.89995	test-rmse:0.87817	test-hr_err:35.03725
# [5]	train-rmse:1.32940	train-hr_err:33.57163	test-rmse:0.87469	test-hr_err:34.26931
# [10]	train-rmse:1.32445	train-hr_err:31.87282	test-rmse:0.87125	test-hr_err:27.57571
# [15]	train-rmse:1.31954	train-hr_err:28.89269	test-rmse:0.86787	test-hr_err:27.79855
# [20]	train-rmse:1.31465	train-hr_err:30.55199	test-rmse:0.86455	test-hr_err:28.57307
# [24]	train-rmse:1.31076	train-hr_err:31.89511	test-rmse:0.86192	test-hr_err:30.20768
#
#
# On batch 5 of 5:
# [0]	train-rmse:0.97635	train-hr_err:33.73661	test-rmse:0.86229	test-hr_err:29.19729
# [5]	train-rmse:0.97969	train-hr_err:35.99039	test-rmse:0.86421	test-hr_err:28.07748
# [10]	train-rmse:0.98330	train-hr_err:36.53883	test-rmse:0.86646	test-hr_err:29.83638
# [15]	train-rmse:0.98706	train-hr_err:35.47219	test-rmse:0.86894	test-hr_err:32.16499
# [19]	train-rmse:0.99009	train-hr_err:35.51878	test-rmse:0.87095	test-hr_err:31.93281
# Fintuning...
# [0]	train-rmse:1.33609	train-hr_err:35.38935	test-rmse:0.87081	test-hr_err:32.29506
# [5]	train-rmse:1.33082	train-hr_err:34.90081	test-rmse:0.86763	test-hr_err:30.41790
# [10]	train-rmse:1.32559	train-hr_err:33.22328	test-rmse:0.86447	test-hr_err:31.76659
# [13]	train-rmse:1.32247	train-hr_err:33.23266	test-rmse:0.86261	test-hr_err:33.46879
# Finished training in 0:02:29.429203
# Number of samples in dataset: 34968
#
#
# On batch 1 of 5:
# [0]	train-rmse:0.89965	train-hr_err:58.53449	test-rmse:0.85650	test-hr_err:24.90317
# [5]	train-rmse:0.90341	train-hr_err:50.39996	test-rmse:0.85861	test-hr_err:31.59843
# [10]	train-rmse:0.90722	train-hr_err:47.16496	test-rmse:0.86072	test-hr_err:27.89467
# [15]	train-rmse:0.91104	train-hr_err:47.16594	test-rmse:0.86288	test-hr_err:28.03630
# [18]	train-rmse:0.91334	train-hr_err:47.16594	test-rmse:0.86418	test-hr_err:27.17965
# Fintuning...
# [0]	train-rmse:1.29177	train-hr_err:48.23876	test-rmse:0.86400	test-hr_err:25.40710
# [5]	train-rmse:1.28648	train-hr_err:44.00548	test-rmse:0.86090	test-hr_err:18.31728
# [10]	train-rmse:1.28121	train-hr_err:37.63666	test-rmse:0.85785	test-hr_err:19.00965
# [15]	train-rmse:1.27597	train-hr_err:25.85752	test-rmse:0.85484	test-hr_err:19.23363
# [20]	train-rmse:1.27076	train-hr_err:30.79185	test-rmse:0.85186	test-hr_err:18.65805
# [25]	train-rmse:1.26558	train-hr_err:41.16251	test-rmse:0.84892	test-hr_err:24.29367
# [27]	train-rmse:1.26352	train-hr_err:42.77135	test-rmse:0.84776	test-hr_err:26.12360
#
#
# On batch 2 of 5:
# [0]	train-rmse:0.90628	train-hr_err:10.37695	test-rmse:0.84813	test-hr_err:26.97737
# [5]	train-rmse:0.90996	train-hr_err:9.35596	test-rmse:0.85003	test-hr_err:20.21859
# [10]	train-rmse:0.91366	train-hr_err:8.20056	test-rmse:0.85201	test-hr_err:19.18605
# [15]	train-rmse:0.91738	train-hr_err:4.76825	test-rmse:0.85402	test-hr_err:20.90464
# [20]	train-rmse:0.92113	train-hr_err:8.00460	test-rmse:0.85608	test-hr_err:22.65773
# [21]	train-rmse:0.92188	train-hr_err:9.10307	test-rmse:0.85650	test-hr_err:23.18032
# Fintuning...
# [0]	train-rmse:1.27831	train-hr_err:7.96399	test-rmse:0.85638	test-hr_err:23.77731
# [5]	train-rmse:1.27319	train-hr_err:5.65628	test-rmse:0.85365	test-hr_err:24.37333
# [10]	train-rmse:1.26810	train-hr_err:4.86590	test-rmse:0.85096	test-hr_err:24.08497
# [15]	train-rmse:1.26304	train-hr_err:6.03575	test-rmse:0.84832	test-hr_err:24.86341
# [16]	train-rmse:1.26203	train-hr_err:6.03575	test-rmse:0.84780	test-hr_err:25.26416
#
#
# On batch 3 of 5:
# [0]	train-rmse:0.71877	train-hr_err:24.15385	test-rmse:0.84826	test-hr_err:25.26416
# [5]	train-rmse:0.72230	train-hr_err:24.14057	test-rmse:0.85057	test-hr_err:25.79582
# [10]	train-rmse:0.72586	train-hr_err:26.42392	test-rmse:0.85293	test-hr_err:25.04028
# [15]	train-rmse:0.72946	train-hr_err:26.09363	test-rmse:0.85533	test-hr_err:25.46795
# [20]	train-rmse:0.73309	train-hr_err:26.09363	test-rmse:0.85776	test-hr_err:26.14926
# [25]	train-rmse:0.73675	train-hr_err:24.09152	test-rmse:0.86023	test-hr_err:24.58376
# [30]	train-rmse:0.74044	train-hr_err:25.31445	test-rmse:0.86271	test-hr_err:23.87760
# [35]	train-rmse:0.74418	train-hr_err:24.22887	test-rmse:0.86526	test-hr_err:23.89070
# [40]	train-rmse:0.74796	train-hr_err:25.44244	test-rmse:0.86788	test-hr_err:23.58803
# [45]	train-rmse:0.75176	train-hr_err:26.50321	test-rmse:0.87045	test-hr_err:23.53655
# [50]	train-rmse:0.75560	train-hr_err:26.50321	test-rmse:0.87306	test-hr_err:24.22023
# [55]	train-rmse:0.75946	train-hr_err:26.50321	test-rmse:0.87571	test-hr_err:24.06778
# [60]	train-rmse:0.76323	train-hr_err:25.70159	test-rmse:0.87838	test-hr_err:25.91976
# [61]	train-rmse:0.76398	train-hr_err:25.70159	test-rmse:0.87892	test-hr_err:26.33853
# Fintuning...
# [0]	train-rmse:1.20716	train-hr_err:25.67106	test-rmse:0.87878	test-hr_err:26.33853
# [5]	train-rmse:1.20188	train-hr_err:26.89555	test-rmse:0.87540	test-hr_err:26.35317
# [7]	train-rmse:1.19978	train-hr_err:26.89555	test-rmse:0.87406	test-hr_err:26.79173
#
#
# On batch 4 of 5:
# [0]	train-rmse:0.83547	train-hr_err:34.19361	test-rmse:0.87375	test-hr_err:26.50349
# [5]	train-rmse:0.83872	train-hr_err:32.42050	test-rmse:0.87557	test-hr_err:25.87310
# [10]	train-rmse:0.84200	train-hr_err:31.93672	test-rmse:0.87743	test-hr_err:25.78798
# [15]	train-rmse:0.84530	train-hr_err:19.68521	test-rmse:0.87953	test-hr_err:23.23140
# [20]	train-rmse:0.84864	train-hr_err:22.15334	test-rmse:0.88196	test-hr_err:21.27874
# [25]	train-rmse:0.85202	train-hr_err:23.23206	test-rmse:0.88441	test-hr_err:20.06654
# [30]	train-rmse:0.85540	train-hr_err:22.08590	test-rmse:0.88685	test-hr_err:19.71917
# [35]	train-rmse:0.85879	train-hr_err:19.75888	test-rmse:0.88928	test-hr_err:19.93946
# [40]	train-rmse:0.86221	train-hr_err:20.82318	test-rmse:0.89172	test-hr_err:21.42597
# [45]	train-rmse:0.86565	train-hr_err:19.66371	test-rmse:0.89419	test-hr_err:20.90305
# [50]	train-rmse:0.86912	train-hr_err:19.64236	test-rmse:0.89668	test-hr_err:21.36191
# Fintuning...
# [0]	train-rmse:1.32684	train-hr_err:18.75130	test-rmse:0.89596	test-hr_err:21.78048
# [5]	train-rmse:1.32151	train-hr_err:17.79972	test-rmse:0.89234	test-hr_err:21.79268
# [10]	train-rmse:1.31620	train-hr_err:17.78132	test-rmse:0.88875	test-hr_err:21.03435
# [15]	train-rmse:1.31093	train-hr_err:18.53759	test-rmse:0.88522	test-hr_err:20.59491
# [20]	train-rmse:1.30569	train-hr_err:19.04886	test-rmse:0.88172	test-hr_err:19.05423
# [25]	train-rmse:1.30048	train-hr_err:16.47127	test-rmse:0.87825	test-hr_err:19.68002
# [26]	train-rmse:1.29944	train-hr_err:17.57472	test-rmse:0.87757	test-hr_err:19.68002
#
#
# On batch 5 of 5:
# [0]	train-rmse:0.78367	train-hr_err:22.93038	test-rmse:0.87814	test-hr_err:19.68002
# [5]	train-rmse:0.78705	train-hr_err:20.98974	test-rmse:0.88103	test-hr_err:19.25649
# [10]	train-rmse:0.79045	train-hr_err:22.21104	test-rmse:0.88395	test-hr_err:19.24842
# [15]	train-rmse:0.79388	train-hr_err:20.83112	test-rmse:0.88691	test-hr_err:18.79114
# [20]	train-rmse:0.79734	train-hr_err:19.69714	test-rmse:0.88992	test-hr_err:19.12702
# [25]	train-rmse:0.80084	train-hr_err:20.52550	test-rmse:0.89296	test-hr_err:18.34956
# [30]	train-rmse:0.80436	train-hr_err:21.17113	test-rmse:0.89605	test-hr_err:17.55971
# [35]	train-rmse:0.80791	train-hr_err:21.10024	test-rmse:0.89917	test-hr_err:19.47329
# [40]	train-rmse:0.81149	train-hr_err:22.18058	test-rmse:0.90234	test-hr_err:18.12397
# [45]	train-rmse:0.81513	train-hr_err:24.30806	test-rmse:0.90547	test-hr_err:17.58670
# [48]	train-rmse:0.81735	train-hr_err:25.42175	test-rmse:0.90736	test-hr_err:17.79692
# Fintuning...
# [0]	train-rmse:1.28688	train-hr_err:23.71074	test-rmse:0.90728	test-hr_err:19.05503
# [5]	train-rmse:1.28134	train-hr_err:21.88835	test-rmse:0.90370	test-hr_err:17.20896
# [10]	train-rmse:1.27584	train-hr_err:22.99014	test-rmse:0.90015	test-hr_err:16.89224
# [15]	train-rmse:1.27036	train-hr_err:21.92110	test-rmse:0.89658	test-hr_err:16.80944
# [20]	train-rmse:1.26492	train-hr_err:22.98510	test-rmse:0.89302	test-hr_err:16.84629
# [22]	train-rmse:1.26275	train-hr_err:22.93126	test-rmse:0.89161	test-hr_err:18.94043
# Finished training in 0:03:41.438098
# Number of samples in dataset: 34968
#
#
# On batch 1 of 5:
# [0]	train-rmse:0.59544	train-hr_err:14.04706	test-rmse:0.85344	test-hr_err:26.78425
# [5]	train-rmse:0.59987	train-hr_err:14.04706	test-rmse:0.85621	test-hr_err:26.78425
# [10]	train-rmse:0.60433	train-hr_err:12.82569	test-rmse:0.85903	test-hr_err:27.90633
# [15]	train-rmse:0.60883	train-hr_err:11.60432	test-rmse:0.86188	test-hr_err:26.99648
# [20]	train-rmse:0.61338	train-hr_err:11.58098	test-rmse:0.86478	test-hr_err:26.92486
# [23]	train-rmse:0.61612	train-hr_err:11.58098	test-rmse:0.86653	test-hr_err:26.93124
# ...
# [13]	train-rmse:1.31224	train-hr_err:13.42898	test-rmse:0.83104	test-hr_err:23.28391
#
#
# On batch 5 of 5:
# [0]	train-rmse:0.76516	train-hr_err:33.11540	test-rmse:0.83130	test-hr_err:23.28391
# [5]	train-rmse:0.76842	train-hr_err:34.28217	test-rmse:0.83261	test-hr_err:21.59999
# [10]	train-rmse:0.77179	train-hr_err:34.85708	test-rmse:0.83441	test-hr_err:22.35721
# [15]	train-rmse:0.77521	train-hr_err:35.45354	test-rmse:0.83631	test-hr_err:23.60660
# [20]	train-rmse:0.77863	train-hr_err:35.46479	test-rmse:0.83806	test-hr_err:21.61556
# [25]	train-rmse:0.78207	train-hr_err:33.29971	test-rmse:0.83985	test-hr_err:21.29686
# Fintuning...
# [0]	train-rmse:1.21038	train-hr_err:31.50117	test-rmse:0.83910	test-hr_err:21.70611
# [5]	train-rmse:1.20530	train-hr_err:32.56495	test-rmse:0.83537	test-hr_err:22.12359
# [8]	train-rmse:1.20226	train-hr_err:31.48992	test-rmse:0.83318	test-hr_err:23.35733
# Finished training in 0:03:06.221688
# /Users/samuelhmorton/opt/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3441: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/samuelhmorton/opt/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/samuelhmorton/opt/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3441: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/samuelhmorton/opt/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/samuelhmorton/opt/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3441: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/samuelhmorton/opt/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/samuelhmorton/opt/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3441: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/samuelhmorton/opt/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/samuelhmorton/opt/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3441: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/samuelhmorton/opt/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/samuelhmorton/opt/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3441: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/samuelhmorton/opt/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/samuelhmorton/opt/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3441: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/samuelhmorton/opt/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/samuelhmorton/opt/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3441: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/samuelhmorton/opt/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/samuelhmorton/opt/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3441: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/samuelhmorton/opt/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/samuelhmorton/opt/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3441: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/samuelhmorton/opt/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/samuelhmorton/opt/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3441: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/samuelhmorton/opt/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/samuelhmorton/opt/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3441: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/samuelhmorton/opt/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/samuelhmorton/opt/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3441: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/samuelhmorton/opt/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/samuelhmorton/opt/anaconda3/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:119: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   ConvergenceWarning,
# /Users/samuelhmorton/opt/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3441: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/samuelhmorton/opt/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/samuelhmorton/opt/anaconda3/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:119: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   ConvergenceWarning,
# /Users/samuelhmorton/opt/anaconda3/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:119: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   ConvergenceWarning,
# /Users/samuelhmorton/opt/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3441: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/samuelhmorton/opt/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/samuelhmorton/opt/anaconda3/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:119: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   ConvergenceWarning,
# /Users/samuelhmorton/opt/anaconda3/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:119: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   ConvergenceWarning,
# /Users/samuelhmorton/opt/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3441: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/samuelhmorton/opt/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/samuelhmorton/opt/anaconda3/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:119: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   ConvergenceWarning,
# /Users/samuelhmorton/opt/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3441: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/samuelhmorton/opt/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/samuelhmorton/opt/anaconda3/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:119: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   ConvergenceWarning,
# /Users/samuelhmorton/opt/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3441: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/samuelhmorton/opt/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/samuelhmorton/opt/anaconda3/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:119: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   ConvergenceWarning,
# /Users/samuelhmorton/opt/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3441: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/samuelhmorton/opt/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/samuelhmorton/opt/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3441: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/samuelhmorton/opt/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/samuelhmorton/opt/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3441: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/samuelhmorton/opt/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/samuelhmorton/opt/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3441: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/samuelhmorton/opt/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/samuelhmorton/opt/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3441: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/samuelhmorton/opt/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/samuelhmorton/opt/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3441: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/samuelhmorton/opt/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/samuelhmorton/opt/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3441: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/samuelhmorton/opt/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/samuelhmorton/opt/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3441: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/samuelhmorton/opt/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/samuelhmorton/opt/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3441: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/samuelhmorton/opt/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/samuelhmorton/opt/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3441: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/samuelhmorton/opt/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/samuelhmorton/opt/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3441: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/samuelhmorton/opt/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/samuelhmorton/opt/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3441: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/samuelhmorton/opt/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/samuelhmorton/opt/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3441: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/samuelhmorton/opt/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/samuelhmorton/opt/anaconda3/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:119: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   ConvergenceWarning,
# /Users/samuelhmorton/opt/anaconda3/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:119: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   ConvergenceWarning,
# /Users/samuelhmorton/opt/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3441: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/samuelhmorton/opt/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/samuelhmorton/opt/anaconda3/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:119: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   ConvergenceWarning,
# /Users/samuelhmorton/opt/anaconda3/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:119: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   ConvergenceWarning,
# /Users/samuelhmorton/opt/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3441: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/samuelhmorton/opt/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/samuelhmorton/opt/anaconda3/lib/python3.7/site-packages/sklearn/decomposition/_fastica.py:119: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   ConvergenceWarning,
# /Users/samuelhmorton/opt/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3441: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/samuelhmorton/opt/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/samuelhmorton/opt/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3441: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/samuelhmorton/opt/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
def analyze_res(res):

    means = {
    }

    for subject in res:
        means[subject] = {}

        for mod in res[subject]:
            mod_run = res[subject][mod]

            reg_runs = mod_run[0]
            noisy_runs = mod_run[1]
            dim_runs = mod_run[2]
            bright_runs = mod_run[3]

            reg_means = {
                'mse': (np.nanmean([run['mse'] for run in reg_runs]), np.nanstd([run['mse'] for run in reg_runs])),
                'hr_err': (np.nanmean([run['hr_err'] for run in reg_runs]), np.nanstd([run['hr_err'] for run in reg_runs])),
                'hrv_err': (np.nanmean([run['hrv_err'] for run in reg_runs]), np.nanstd([run['hrv_err'] for run in reg_runs])),
                'peaks_err': (np.nanmean([run['peaks_err'] for run in reg_runs]), np.nanstd([run['peaks_err'] for run in reg_runs]))
            }
            noisy_means = {
                'mse': (np.nanmean([run['mse'] for run in noisy_runs]), np.nanstd([run['mse'] for run in noisy_runs])),
                'hr_err': (np.nanmean([run['hr_err'] for run in noisy_runs]), np.nanstd([run['hr_err'] for run in noisy_runs])),
                'hrv_err': (np.nanmean([run['hrv_err'] for run in noisy_runs]), np.nanstd([run['hrv_err'] for run in noisy_runs])),
                'peaks_err': (np.nanmean([run['peaks_err'] for run in noisy_runs]), np.nanstd([run['peaks_err'] for run in noisy_runs]))
            }
            dim_means = {
                'mse': (np.nanmean([run['mse'] for run in dim_runs]), np.nanstd([run['mse'] for run in dim_runs])),
                'hr_err': (np.nanmean([run['hr_err'] for run in dim_runs]), np.nanstd([run['hr_err'] for run in dim_runs])),
                'hrv_err': (np.nanmean([run['hrv_err'] for run in dim_runs]), np.nanstd([run['hrv_err'] for run in dim_runs])),
                'peaks_err': (np.nanmean([run['peaks_err'] for run in dim_runs]), np.nanstd([run['peaks_err'] for run in dim_runs]))
            }
            bright_means = {
                'mse': (np.nanmean([run['mse'] for run in bright_runs]), np.nanstd([run['mse'] for run in bright_runs])),
                'hr_err': (np.nanmean([run['hr_err'] for run in bright_runs]), np.nanstd([run['hr_err'] for run in bright_runs])),
                'hrv_err': (np.nanmean([run['hrv_err'] for run in bright_runs]), np.nanstd([run['hrv_err'] for run in bright_runs])),
                'peaks_err': (np.nanmean([run['peaks_err'] for run in bright_runs]), np.nanstd([run['peaks_err'] for run in bright_runs]))
            }

            means[subject][mod] = {
                'reg': reg_means,
                'noisy': noisy_means,
                'dim': dim_means,
                'bright': bright_means
            }

    return means

ana = analyze_res(res)

# %%
best
# Out:
# 3

# %%
reg_mses = []
reg_hrs = []
reg_hrvs = []
reg_peaks = []
noisy_mses = []
noisy_hrs = []
noisy_hrvs = []
noisy_peaks = []
dim_mses = []
dim_hrs = []
dim_hrvs = []
dim_peaks = []
bright_mses = []
bright_hrs = []
bright_hrvs = []
bright_peaks = []

rlines = []
nlines = []
dlines = []
blines = []

for subject in ana:
    print(f'Subject {subject}:')
    reg = []
    noisy = []
    dim = []
    bright = []

    for mod in ana[subject]:
        reg.append(ana[subject][mod]['reg'])
        noisy.append(ana[subject][mod]['noisy'])
        dim.append(ana[subject][mod]['dim'])
        bright.append(ana[subject][mod]['bright'])
    

    best = 0
    for i, mod in enumerate(reg):
        if mod['hr_err'] < reg[best]['hr_err']:
            best = i
    reg_mse = reg[best]['mse']
    reg_hr = reg[best]['hr_err']
    reg_hrv = reg[best]['hrv_err']
    reg_peak = reg[best]['peaks_err']

    # reg_mse = np.nanmean([mod['mse'] for mod in reg])
    # reg_hr = np.nanmean([mod['hr_err'] for mod in reg])
    # reg_hrv = np.nanmean([mod['hrv_err'] for mod in reg])
    # reg_peak = np.nanmean([mod['peaks_err'] for mod in reg])

    reg_mses.append(reg_mse)
    reg_hrs.append(reg_hr)
    reg_hrvs.append(reg_hrv)
    reg_peaks.append(reg_peak)

    print(f'\tReg MSE: {reg_mse}')
    print(f'\tReg HR: {reg_hr}')
    print(f'\tReg HRV: {reg_hrv}')
    print(f'\tReg Peaks: {reg_peak}')
    line = f'& {subject} & {round(reg_hr[0], 2)} $\pm$ {round(reg_hr[1], 2)} & {round(reg_hrv[0], 2)} $\pm$ {round(reg_hrv[1], 2)} & {round(reg_peak[0], 2)} $\pm$ {round(reg_peak[1], 2)} \\'
    print(f'Line: {line}')
    rlines.append(line)
    print()

    noisy_mse = noisy[best]['mse']
    noisy_hr = noisy[best]['hr_err']
    noisy_hrv = noisy[best]['hrv_err']
    noisy_peak = noisy[best]['peaks_err']

    # noisy_mse = np.nanmean([mod['mse'] for mod in noisy])
    # noisy_hr = np.nanmean([mod['hr_err'] for mod in noisy])
    # noisy_hrv = np.nanmean([mod['hrv_err'] for mod in noisy])
    # noisy_peak = np.nanmean([mod['peaks_err'] for mod in noisy])

    noisy_mses.append(noisy_mse)
    noisy_hrs.append(noisy_hr)
    noisy_hrvs.append(noisy_hrv)
    noisy_peaks.append(noisy_peak)

    print(f'\tNoisy MSE: {noisy_mse}')
    print(f'\tNoisy HR: {noisy_hr}')
    print(f'\tNoisy HRV: {noisy_hrv}')
    print(f'\tNoisy Peaks: {noisy_peak}')
    line = f'& {subject} & {round(noisy_hr[0], 2)} $\pm$ {round(noisy_hr[1], 2)} & {round(noisy_hrv[0], 2)} $\pm$ {round(noisy_hrv[1], 2)} & {round(noisy_peak[0], 2)} $\pm$ {round(noisy_peak[1], 2)} \\'
    print(f'Line: {line}')
    nlines.append(line)
    print()

    dim_mse = dim[best]['mse']
    dim_hr = dim[best]['hr_err']
    dim_hrv = dim[best]['hrv_err']
    dim_peak = dim[best]['peaks_err']

    # dim_mse = np.nanmean([mod['mse'] for mod in dim])
    # dim_hr = np.nanmean([mod['hr_err'] for mod in dim])
    # dim_hrv = np.nanmean([mod['hrv_err'] for mod in dim])
    # dim_peak = np.nanmean([mod['peaks_err'] for mod in dim])

    dim_mses.append(dim_mse)
    dim_hrs.append(dim_hr)
    dim_hrvs.append(dim_hrv)
    dim_peaks.append(dim_peak)

    print(f'\tDim MSE: {dim_mse}')
    print(f'\tDim HR: {dim_hr}')
    print(f'\tDim HRV: {dim_hrv}')
    print(f'\tDim Peaks: {dim_peak}')
    line = f'& {subject} & {round(dim_hr[0], 2)} $\pm$ {round(dim_hr[1], 2)} & {round(dim_hrv[0], 2)} $\pm$ {round(dim_hrv[1], 2)} & {round(dim_peak[0], 2)} $\pm$ {round(dim_peak[1], 2)} \\'
    print(f'Line: {line}')
    dlines.append(line)
    print()

    bright_mse = bright[best]['mse']
    bright_hr = bright[best]['hr_err']
    bright_hrv = bright[best]['hrv_err']
    bright_peak = bright[best]['peaks_err']

    # bright_mse = np.nanmean([mod['mse'] for mod in bright])
    # bright_hr = np.nanmean([mod['hr_err'] for mod in bright])
    # bright_hrv = np.nanmean([mod['hrv_err'] for mod in bright])
    # bright_peak = np.nanmean([mod['peaks_err'] for mod in bright])

    bright_mses.append(bright_mse)
    bright_hrs.append(bright_hr)
    bright_hrvs.append(bright_hrv)
    bright_peaks.append(bright_peak)

    print(f'\tBright MSE: {bright_mse}')
    print(f'\tBright HR: {bright_hr}')
    print(f'\tBright HRV: {bright_hrv}')
    print(f'\tBright Peaks: {bright_peak}')
    line = f'& {subject} & {round(bright_hr[0], 2)} $\pm$ {round(bright_hr[1], 2)} & {round(bright_hrv[0], 2)} $\pm$ {round(bright_hrv[1], 2)} & {round(bright_peak[0], 2)} $\pm$ {round(bright_peak[1], 2)} \\'
    print(f'Line: {line}')
    blines.append(line)
    print()

print(f'Reg MSE: {np.nanmean(reg_mses)}')
print(f'Reg HR: {np.nanmean(reg_hrs)}')
print(f'Reg HRV: {np.nanmean(reg_hrvs)}')
print(f'Reg Peaks: {np.nanmean(reg_peaks)}')
print()
print(f'Noisy MSE: {np.nanmean(noisy_mses)}')
print(f'Noisy HR: {np.nanmean(noisy_hrs)}')
print(f'Noisy HRV: {np.nanmean(noisy_hrvs)}')
print(f'Noisy Peaks: {np.nanmean(noisy_peaks)}')
print()

print(f'Dim MSE: {np.nanmean(dim_mses)}')
print(f'Dim HR: {np.nanmean(dim_hrs)}')
print(f'Dim HRV: {np.nanmean(dim_hrvs)}')
print(f'Dim Peaks: {np.nanmean(dim_peaks)}')
print()

print(f'Bright MSE: {np.nanmean(bright_mses)}')
print(f'Bright HR: {np.nanmean(bright_hrs)}')
print(f'Bright HRV: {np.nanmean(bright_hrvs)}')
print(f'Bright Peaks: {np.nanmean(bright_peaks)}')
print()

print('Reg lines:')
for line in rlines:
    print(line)
print()
print('Noisy lines')
for line in nlines:
    print(line)
print()
print('Dim lines')
for line in dlines:
    print(line)
print()
print('Bright lines')
for line in blines:
    print(line)
print()
# Out:
# Subject 1:
# 	Reg MSE: (0.08976663398303884, 0.029900551133669913)
# 	Reg HR: (12.189578524839055, 10.624296286172925)
# 	Reg HRV: (0.8519938250767238, 0.8205597399878555)
# 	Reg Peaks: (3.074074074074074, 2.8405258501946684)
# Line: & 1 & 12.19 $\pm$ 10.62 & 0.85 $\pm$ 0.82 & 3.07 $\pm$ 2.84 \
#
# 	Noisy MSE: (0.08279048617279333, 0.025120079566378836)
# 	Noisy HR: (18.755637085909434, 15.441632047026884)
# 	Noisy HRV: (1.1120036967730154, 1.1522770979277241)
# 	Noisy Peaks: (5.555555555555555, 2.9731307022799225)
# Line: & 1 & 18.76 $\pm$ 15.44 & 1.11 $\pm$ 1.15 & 5.56 $\pm$ 2.97 \
#
# 	Dim MSE: (0.09088684017304736, 0.029988548144971722)
# 	Dim HR: (21.255694929310565, 19.443953760902684)
# 	Dim HRV: (0.7193499184224182, 0.5883405291090711)
# 	Dim Peaks: (5.222222222222222, 4.012326685615064)
# Line: & 1 & 21.26 $\pm$ 19.44 & 0.72 $\pm$ 0.59 & 5.22 $\pm$ 4.01 \
#
# 	Bright MSE: (0.11115975033372605, 0.03940469970062928)
# 	Bright HR: (22.789680294127745, 20.941670699820598)
# 	Bright HRV: (1.0836017982507788, 1.0646695403965207)
# 	Bright Peaks: (5.7407407407407405, 5.203934356295868)
# Line: & 1 & 22.79 $\pm$ 20.94 & 1.08 $\pm$ 1.06 & 5.74 $\pm$ 5.2 \
#
# Subject 2:
# 	Reg MSE: (0.09892886568049858, 0.02483710171340823)
# 	Reg HR: (7.453515124913897, 4.960024578158748)
# 	Reg HRV: (0.5825654929021493, 0.29350563078940517)
# 	Reg Peaks: (1.9090909090909092, 1.8317674254190808)
# Line: & 2 & 7.45 $\pm$ 4.96 & 0.58 $\pm$ 0.29 & 1.91 $\pm$ 1.83 \
#
# 	Noisy MSE: (0.0968308816542911, 0.028079120336968338)
# 	Noisy HR: (13.084077990024246, 10.275528346950226)
# 	Noisy HRV: (0.7418909995329476, 0.655627471161818)
# 	Noisy Peaks: (3.1363636363636362, 2.2622485705689646)
# Line: & 2 & 13.08 $\pm$ 10.28 & 0.74 $\pm$ 0.66 & 3.14 $\pm$ 2.26 \
#
# 	Dim MSE: (0.09445425587395345, 0.030863979053759906)
# 	Dim HR: (24.41896837955171, 15.976210639367727)
# 	Dim HRV: (1.7887779027623723, 1.3599720323084938)
# 	Dim Peaks: (8.363636363636363, 3.268937199339128)
# Line: & 2 & 24.42 $\pm$ 15.98 & 1.79 $\pm$ 1.36 & 8.36 $\pm$ 3.27 \
#
# 	Bright MSE: (0.09158972489790983, 0.026822949284364815)
# 	Bright HR: (25.105487576908384, 16.900819516925186)
# 	Bright HRV: (1.6921632377088254, 1.5897993958265384)
# 	Bright Peaks: (7.5, 3.7142232761984766)
# Line: & 2 & 25.11 $\pm$ 16.9 & 1.69 $\pm$ 1.59 & 7.5 $\pm$ 3.71 \
#
# Subject 3:
# 	Reg MSE: (0.07059233791459572, 0.021030632085640082)
# 	Reg HR: (15.710562820869546, 10.642685176812048)
# 	Reg HRV: (0.4525870384609297, 0.3977613245549989)
# 	Reg Peaks: (4.0, 3.2118202741878648)
# Line: & 3 & 15.71 $\pm$ 10.64 & 0.45 $\pm$ 0.4 & 4.0 $\pm$ 3.21 \
#
# 	Noisy MSE: (0.06866261849054076, 0.018826487220973052)
# 	Noisy HR: (16.823027719975123, 17.414842359599156)
# 	Noisy HRV: (1.175643583452444, 0.7735911647505628)
# 	Noisy Peaks: (4.052631578947368, 3.501483658627347)
# Line: & 3 & 16.82 $\pm$ 17.41 & 1.18 $\pm$ 0.77 & 4.05 $\pm$ 3.5 \
#
# 	Dim MSE: (0.05955964377873504, 0.014148321861602007)
# 	Dim HR: (25.988187494378703, 18.26747543700396)
# 	Dim HRV: (1.6516822718796065, 1.9371178763641344)
# 	Dim Peaks: (8.68421052631579, 3.5696473595396148)
# Line: & 3 & 25.99 $\pm$ 18.27 & 1.65 $\pm$ 1.94 & 8.68 $\pm$ 3.57 \
#
# 	Bright MSE: (0.06308466125891422, 0.020783939288962598)
# 	Bright HR: (29.143994879156594, 24.71958032263792)
# 	Bright HRV: (0.9214188785511516, 1.241033821903799)
# 	Bright Peaks: (7.684210526315789, 4.4254364230690335)
# Line: & 3 & 29.14 $\pm$ 24.72 & 0.92 $\pm$ 1.24 & 7.68 $\pm$ 4.43 \
#
# Subject 4:
# 	Reg MSE: (0.061605741327448595, 0.011356279328343362)
# 	Reg HR: (23.647254021237426, 10.850606767724374)
# 	Reg HRV: (0.44258182755888525, 0.16031492776745573)
# 	Reg Peaks: (6.666666666666667, 4.4969125210773475)
# Line: & 4 & 23.65 $\pm$ 10.85 & 0.44 $\pm$ 0.16 & 6.67 $\pm$ 4.5 \
#
# 	Noisy MSE: (0.05962336519404293, 0.021222721282270533)
# 	Noisy HR: (23.97262817237805, 12.906029443201804)
# 	Noisy HRV: (0.12921756626539785, 0.15677135871459583)
# 	Noisy Peaks: (5.666666666666667, 2.357022603955158)
# Line: & 4 & 23.97 $\pm$ 12.91 & 0.13 $\pm$ 0.16 & 5.67 $\pm$ 2.36 \
#
# 	Dim MSE: (0.04745032694065065, 0.009029428705010691)
# 	Dim HR: (8.408971045150416, 8.941265512117313)
# 	Dim HRV: (1.1768186466248307, 0.38159774493980836)
# 	Dim Peaks: (6.333333333333333, 1.8856180831641267)
# Line: & 4 & 8.41 $\pm$ 8.94 & 1.18 $\pm$ 0.38 & 6.33 $\pm$ 1.89 \
#
# 	Bright MSE: (0.05211766625743932, 0.01628034537334414)
# 	Bright HR: (15.729440869796449, 3.8185562907609616)
# 	Bright HRV: (0.3825315771256584, 0.19202695912360632)
# 	Bright Peaks: (5.333333333333333, 2.8674417556808756)
# Line: & 4 & 15.73 $\pm$ 3.82 & 0.38 $\pm$ 0.19 & 5.33 $\pm$ 2.87 \
#
# Subject 5:
# 	Reg MSE: (0.1038432437759301, 0.031606979428240166)
# 	Reg HR: (40.39354440357261, 13.471361560557757)
# 	Reg HRV: (0.7272813437688156, 0.4334379938907872)
# 	Reg Peaks: (10.521739130434783, 3.474998470032711)
# Line: & 5 & 40.39 $\pm$ 13.47 & 0.73 $\pm$ 0.43 & 10.52 $\pm$ 3.47 \
#
# 	Noisy MSE: (0.09854664287353664, 0.018350224104505968)
# 	Noisy HR: (50.359591121661836, 10.788450019092041)
# 	Noisy HRV: (0.9899401082719749, 0.4885013865447693)
# 	Noisy Peaks: (12.956521739130435, 2.789393901277468)
# Line: & 5 & 50.36 $\pm$ 10.79 & 0.99 $\pm$ 0.49 & 12.96 $\pm$ 2.79 \
#
# 	Dim MSE: (0.08244004009810964, 0.01676532591502823)
# 	Dim HR: (53.295594086814184, 26.598228448441272)
# 	Dim HRV: (1.2350516064306256, 1.1376365475755439)
# 	Dim Peaks: (20.73913043478261, 4.244867912159625)
# Line: & 5 & 53.3 $\pm$ 26.6 & 1.24 $\pm$ 1.14 & 20.74 $\pm$ 4.24 \
#
# 	Bright MSE: (0.08861423718705425, 0.02215528676731828)
# 	Bright HR: (69.39676761876868, 21.890152166037037)
# 	Bright HRV: (1.5532131276335153, 1.3274811635511716)
# 	Bright Peaks: (20.08695652173913, 5.003590393327236)
# Line: & 5 & 69.4 $\pm$ 21.89 & 1.55 $\pm$ 1.33 & 20.09 $\pm$ 5.0 \
#
# Subject 6:
# 	Reg MSE: (0.10215229851985966, 0.02050536806840336)
# 	Reg HR: (16.379841359368424, 8.857451844433333)
# 	Reg HRV: (0.6318311410214537, 0.317692029175083)
# 	Reg Peaks: (4.590909090909091, 2.9948302563689335)
# Line: & 6 & 16.38 $\pm$ 8.86 & 0.63 $\pm$ 0.32 & 4.59 $\pm$ 2.99 \
#
# 	Noisy MSE: (0.10487937558795105, 0.02032379500021298)
# 	Noisy HR: (25.59045396490169, 20.675939939506062)
# 	Noisy HRV: (1.4454361757782017, 1.7944036160227168)
# 	Noisy Peaks: (9.636363636363637, 5.347433152673725)
# Line: & 6 & 25.59 $\pm$ 20.68 & 1.45 $\pm$ 1.79 & 9.64 $\pm$ 5.35 \
#
# 	Dim MSE: (0.1090240858694549, 0.023006600371894902)
# 	Dim HR: (29.602178753626525, 16.908805317962724)
# 	Dim HRV: (1.4806075415796818, 1.289180551862554)
# 	Dim Peaks: (8.045454545454545, 4.4053404855230465)
# Line: & 6 & 29.6 $\pm$ 16.91 & 1.48 $\pm$ 1.29 & 8.05 $\pm$ 4.41 \
#
# 	Bright MSE: (0.10845241117865757, 0.0195079458671045)
# 	Bright HR: (25.204564698253623, 19.996360563420755)
# 	Bright HRV: (1.1112209240602338, 1.495272101817894)
# 	Bright Peaks: (6.7727272727272725, 4.8610868423898985)
# Line: & 6 & 25.2 $\pm$ 20.0 & 1.11 $\pm$ 1.5 & 6.77 $\pm$ 4.86 \
#
# Subject 7:
# 	Reg MSE: (0.08116055447721134, 0.015504883668557535)
# 	Reg HR: (19.050639224474295, 10.415633721111812)
# 	Reg HRV: (0.5696704248364246, 0.46993042125758877)
# 	Reg Peaks: (5.090909090909091, 2.538952735230717)
# Line: & 7 & 19.05 $\pm$ 10.42 & 0.57 $\pm$ 0.47 & 5.09 $\pm$ 2.54 \
#
# 	Noisy MSE: (0.09376318433900493, 0.02257070421479581)
# 	Noisy HR: (15.90661926387807, 9.470179103154749)
# 	Noisy HRV: (0.8163659542273546, 0.79273517204514)
# 	Noisy Peaks: (3.4545454545454546, 2.290836939700755)
# Line: & 7 & 15.91 $\pm$ 9.47 & 0.82 $\pm$ 0.79 & 3.45 $\pm$ 2.29 \
#
# 	Dim MSE: (0.10289464376110269, 0.024532835542177424)
# 	Dim HR: (33.07417995193651, 23.174267558666347)
# 	Dim HRV: (0.5056421456667497, 0.4551194976944403)
# 	Dim Peaks: (8.5, 5.852349955359813)
# Line: & 7 & 33.07 $\pm$ 23.17 & 0.51 $\pm$ 0.46 & 8.5 $\pm$ 5.85 \
#
# 	Bright MSE: (0.07952258799866364, 0.018613026377782622)
# 	Bright HR: (17.835319586554427, 16.011273923182195)
# 	Bright HRV: (1.4262249837867462, 2.1572505999209177)
# 	Bright Peaks: (5.318181818181818, 3.4163558952933735)
# Line: & 7 & 17.84 $\pm$ 16.01 & 1.43 $\pm$ 2.16 & 5.32 $\pm$ 3.42 \
#
# Reg MSE: 0.05448510507891753
# Reg HR: 14.617642529589018
# Reg HRV: 0.5108366543606111
# Reg Peaks: 4.088799749613996
#
# Noisy MSE: 0.05425640614559045
# Noisy HR: 18.676045469804244
# Noisy HRV: 0.87317181081919
# Noisy Peaks: 4.712871271189721
#
# Dim MSE: 0.05250320543496419
# Dim HR: 23.239570093945048
# Dim HRV: 1.1219210580871664
# Dim Peaks: 6.651933936174663
#
# Bright MSE: 0.0541506594122765
# Bright HR: 23.5345477861679
# Bright HRV: 1.2312791506898113
# Bright Peaks: 6.280587082520916
#
# Reg lines:
# & 1 & 12.19 $\pm$ 10.62 & 0.85 $\pm$ 0.82 & 3.07 $\pm$ 2.84 \
# & 2 & 7.45 $\pm$ 4.96 & 0.58 $\pm$ 0.29 & 1.91 $\pm$ 1.83 \
# & 3 & 15.71 $\pm$ 10.64 & 0.45 $\pm$ 0.4 & 4.0 $\pm$ 3.21 \
# & 4 & 23.65 $\pm$ 10.85 & 0.44 $\pm$ 0.16 & 6.67 $\pm$ 4.5 \
# & 5 & 40.39 $\pm$ 13.47 & 0.73 $\pm$ 0.43 & 10.52 $\pm$ 3.47 \
# & 6 & 16.38 $\pm$ 8.86 & 0.63 $\pm$ 0.32 & 4.59 $\pm$ 2.99 \
# & 7 & 19.05 $\pm$ 10.42 & 0.57 $\pm$ 0.47 & 5.09 $\pm$ 2.54 \
#
# Noisy lines
# & 1 & 18.76 $\pm$ 15.44 & 1.11 $\pm$ 1.15 & 5.56 $\pm$ 2.97 \
# & 2 & 13.08 $\pm$ 10.28 & 0.74 $\pm$ 0.66 & 3.14 $\pm$ 2.26 \
# & 3 & 16.82 $\pm$ 17.41 & 1.18 $\pm$ 0.77 & 4.05 $\pm$ 3.5 \
# & 4 & 23.97 $\pm$ 12.91 & 0.13 $\pm$ 0.16 & 5.67 $\pm$ 2.36 \
# & 5 & 50.36 $\pm$ 10.79 & 0.99 $\pm$ 0.49 & 12.96 $\pm$ 2.79 \
# & 6 & 25.59 $\pm$ 20.68 & 1.45 $\pm$ 1.79 & 9.64 $\pm$ 5.35 \
# & 7 & 15.91 $\pm$ 9.47 & 0.82 $\pm$ 0.79 & 3.45 $\pm$ 2.29 \
#
# Dim lines
# & 1 & 21.26 $\pm$ 19.44 & 0.72 $\pm$ 0.59 & 5.22 $\pm$ 4.01 \
# & 2 & 24.42 $\pm$ 15.98 & 1.79 $\pm$ 1.36 & 8.36 $\pm$ 3.27 \
# & 3 & 25.99 $\pm$ 18.27 & 1.65 $\pm$ 1.94 & 8.68 $\pm$ 3.57 \
# & 4 & 8.41 $\pm$ 8.94 & 1.18 $\pm$ 0.38 & 6.33 $\pm$ 1.89 \
# & 5 & 53.3 $\pm$ 26.6 & 1.24 $\pm$ 1.14 & 20.74 $\pm$ 4.24 \
# & 6 & 29.6 $\pm$ 16.91 & 1.48 $\pm$ 1.29 & 8.05 $\pm$ 4.41 \
# & 7 & 33.07 $\pm$ 23.17 & 0.51 $\pm$ 0.46 & 8.5 $\pm$ 5.85 \
#
# Bright lines
# & 1 & 22.79 $\pm$ 20.94 & 1.08 $\pm$ 1.06 & 5.74 $\pm$ 5.2 \
# & 2 & 25.11 $\pm$ 16.9 & 1.69 $\pm$ 1.59 & 7.5 $\pm$ 3.71 \
# & 3 & 29.14 $\pm$ 24.72 & 0.92 $\pm$ 1.24 & 7.68 $\pm$ 4.43 \
# & 4 & 15.73 $\pm$ 3.82 & 0.38 $\pm$ 0.19 & 5.33 $\pm$ 2.87 \
# & 5 & 69.4 $\pm$ 21.89 & 1.55 $\pm$ 1.33 & 20.09 $\pm$ 5.0 \
# & 6 & 25.2 $\pm$ 20.0 & 1.11 $\pm$ 1.5 & 6.77 $\pm$ 4.86 \
# & 7 & 17.84 $\pm$ 16.01 & 1.43 $\pm$ 2.16 & 5.32 $\pm$ 3.42 \

# %%
import pywt
from pipeline_v1.wavelet import apply_wavelet
def cwt_morlet_filter(signal, sample_freq=30, f_min=0.67, f_max=4.0, num_steps=200):
    sampling_period = 1.0 / sample_freq

    # Define the wavelet
    wavelet = 'morl'

    # Compute the corresponding scales
    scale_min = pywt.scale2frequency(wavelet, f_min) / sampling_period
    scale_max = pywt.scale2frequency(wavelet, f_max) / sampling_period

    # Create a range of scales
    scales = np.linspace(scale_max, scale_min, num_steps)

    # Compute the CWT
    cwt_coeffs, _ = pywt.cwt(signal, scales, wavelet, sampling_period)

    # Filter the signal
    filtered_signal = np.sum(cwt_coeffs, axis=0)

    return filtered_signal


plt.plot(min_max_scale(pred), label = 'orig')
plt.plot(min_max_scale(cwt_morlet_filter(pred, 64)), label = 'wave')
plt.plot(min_max_scale(apply_wavelet(pred)), label = 'normal')
plt.legend()

# %% [markdown]
# ## Bayesian hyperparameter optimization demonstration

# %%
optimizer = MoodBoostOptimizer(truths)
result = optimizer.optimize(n_calls = 10)
print(result)
